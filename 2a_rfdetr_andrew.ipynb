# %% [markdown]
# # 2a — Object Detection: RF-DETR
#
# **Method implemented in this notebook:**
# - **RF-DETR** (PyTorch)
#
# ## Project dataset structure
# - `./signs.json` (original consolidated annotations at project root)
# - `./signs_coco/images/` (all images, `.jpg` / `.jpeg`)
# - `./signs_coco/result.json` (COCO-format annotations)
#
# ## What this notebook does
# 1. Environment + deterministic setup
# 2. Load COCO dataset, sanity-check classes + samples
# 3. Create a deterministic train/val split + write COCO JSONs (for RF-DETR)
# 4. Train **RF-DETR** object detector
# 5. Evaluate (mAP, qualitative predictions, per-class metrics)
# 6. Save checkpoint + export inference helper
# 7. Quick end-to-end demo on a sample image

# %%
from pathlib import Path
import os, sys, json, random
import numpy as np

import torch
import torchvision

print("Python:", sys.version.split()[0])
print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
if device.type == "cuda":
    print("CUDA:", torch.version.cuda)
    print("GPU:", torch.cuda.get_device_name(0))

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

PROJECT_ROOT = Path(".").resolve()
COCO_ANN = PROJECT_ROOT / "signs_coco" / "result.json"
IMAGES_DIR = PROJECT_ROOT / "signs_coco" / "images"

assert COCO_ANN.exists(), f"Missing COCO annotations: {COCO_ANN}"
assert IMAGES_DIR.exists(), f"Missing images folder: {IMAGES_DIR}"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("COCO_ANN:", COCO_ANN)
print("IMAGES_DIR:", IMAGES_DIR)

img_files = sorted([p for p in IMAGES_DIR.iterdir() if p.suffix.lower() in [".jpg", ".jpeg"]])
print("Images found:", len(img_files))
print("Example image:", img_files[0].name if img_files else "N/A")
# Out:
# Python: 3.11.14
# Torch: 2.8.0+cu128
# TorchVision: 0.23.0+cu128
# Device: cuda
# CUDA: 12.8
# GPU: NVIDIA GeForce RTX 2070 SUPER
# PROJECT_ROOT: /home/yukkami/cv
# COCO_ANN: /home/yukkami/cv/signs_coco/result.json
# IMAGES_DIR: /home/yukkami/cv/signs_coco/images
# Images found: 602
# Example image: 002c644e-Pre_2026_6761.jpg

# %%
from collections import defaultdict, Counter

with open(COCO_ANN, "r", encoding="utf-8") as f:
    coco = json.load(f)

print("Top-level keys:", list(coco.keys()))

images = coco.get("images", [])
annotations = coco.get("annotations", [])
categories = coco.get("categories", [])

print(f"#images: {len(images)}")
print(f"#annotations: {len(annotations)}")
print(f"#categories: {len(categories)}")

cat_id_to_name = {c["id"]: c["name"] for c in categories}
cat_name_to_id = {c["name"]: c["id"] for c in categories}

print("\nFirst 10 categories:")
for c in categories[:10]:
    print(f'  id={c["id"]:<4} name="{c["name"]}"')

ann_counts = Counter([a["category_id"] for a in annotations])
top = ann_counts.most_common(10)
print("\nTop 10 categories by annotation count:")
for cid, cnt in top:
    print(f'  {cat_id_to_name.get(cid, str(cid)):<30} {cnt}')

bad = 0
for a in annotations[:5000]:
    x, y, w, h = a["bbox"]
    if w <= 0 or h <= 0:
        bad += 1
print("\nBBox sanity (sampled): bad bboxes =", bad)

img_id_to_file = {im["id"]: im["file_name"] for im in images}
print("Example mapping:", next(iter(img_id_to_file.items())) if img_id_to_file else "N/A")
# Out:
# Top-level keys: ['images', 'categories', 'annotations', 'info']
# #images: 602
# #annotations: 899
# #categories: 38
#
# First 10 categories:
#   id=0    name="Animal"
#   id=1    name="Back"
#   id=2    name="Blind-Spot Mirror (Convex)"
#   id=3    name="Bump"
#   id=4    name="Circular"
#   id=5    name="Damaged"
#   id=6    name="Front"
#   id=7    name="Give way"
#   id=8    name="Good"
#   id=9    name="Heavily Damaged"
#
# Top 10 categories by annotation count:
#   No Entry (One Way)             179
#   Pedestrian Crossing            122
#   Stop                           92
#   Blind-Spot Mirror (Convex)     85
#   No Turn (left/right)           67
#   Turn (left/right)              62
#   Speed Limit                    52
#   Roundabout Ahead               45
#   No Stopping                    41
#   Give way                       38
#
# BBox sanity (sampled): bad bboxes = 0
# Example mapping: (0, '../../label-studio/data/media/upload/3/5cc76983-IMG_20251125_190933.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

img_to_anns = defaultdict(list)
for a in annotations:
    img_to_anns[a["image_id"]].append(a)

def show_coco_sample(image_id, figsize=(10, 8), max_boxes=30):
    file_name = img_id_to_file[image_id]
    img_path = IMAGES_DIR / file_name
    if not img_path.exists():
        img_path = IMAGES_DIR / Path(file_name).name
    assert img_path.exists(), f"Image not found: {img_path}"

    img = Image.open(img_path).convert("RGB")
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.imshow(img)
    ax.axis("off")

    anns = img_to_anns.get(image_id, [])[:max_boxes]
    for ann in anns:
        x, y, w, h = ann["bbox"]
        cid = ann["category_id"]
        label = cat_id_to_name.get(cid, str(cid))

        rect = patches.Rectangle((x, y), w, h, linewidth=2, fill=False)
        ax.add_patch(rect)
        ax.text(
            x, max(0, y - 3),
            label,
            fontsize=9,
            bbox=dict(facecolor="white", alpha=0.7, edgecolor="none", pad=1),
        )

    ax.set_title(f"{img_path.name} | boxes={len(anns)}", fontsize=12)
    plt.show()

image_ids_with_anns = [im["id"] for im in images if im["id"] in img_to_anns and len(img_to_anns[im["id"]]) > 0]
print("Images with >=1 annotation:", len(image_ids_with_anns))

for _ in range(3):
    iid = random.choice(image_ids_with_anns)
    show_coco_sample(iid)

from PIL import ImageDraw, ImageFont

def draw_predictions(
    img_path,
    preds,
    score_thr=0.3,
    save_path=None,
    rfdetr_model_for_names=None,
    coco_json_for_names=None,
    resize_to=None,
    font_scale=0.06,
):
    img = Image.open(img_path).convert("RGB")
    w0, h0 = img.size

    if resize_to is not None:
        w1, h1 = int(resize_to[0]), int(resize_to[1])
        sx, sy = w1 / w0, h1 / h0
        img = img.resize((w1, h1), resample=Image.BILINEAR)
    else:
        sx = sy = 1.0

    id_to_name = {}
    if coco_json_for_names is not None:
        try:
            with open(coco_json_for_names, "r", encoding="utf-8") as f:
                _c = json.load(f)
            for c in _c.get("categories", []):
                if isinstance(c, dict) and "id" in c and "name" in c:
                    id_to_name[int(c["id"])] = str(c["name"])
        except Exception:
            pass

    xyxy = getattr(preds, "xyxy", None)
    conf = getattr(preds, "confidence", None)
    cls  = getattr(preds, "class_id", None)

    if xyxy is None or cls is None:
        if save_path is not None:
            img.save(save_path)
        return img

    xyxy = np.asarray(xyxy)
    cls = np.asarray(cls).astype(int)
    if conf is None:
        conf = np.ones((len(xyxy),), dtype=float)
    else:
        conf = np.asarray(conf).astype(float)

    draw = ImageDraw.Draw(img)
    try:
        font_size = max(10, int(min(img.size) * float(font_scale)))
        font = ImageFont.truetype("DejaVuSans.ttf", font_size)
    except Exception:
        font = ImageFont.load_default()

    for (x1, y1, x2, y2), c, s in zip(xyxy, cls, conf):
        if float(s) < float(score_thr):
            continue
        x1, y1, x2, y2 = float(x1) * sx, float(y1) * sy, float(x2) * sx, float(y2) * sy
        draw.rectangle([x1, y1, x2, y2], outline="red", width=3)
        name = id_to_name.get(int(c), cat_id_to_name.get(int(c), str(int(c))))
        label = f"{name} {float(s):.2f}"
        tx, ty = x1, max(0, y1 - 14)
        draw.rectangle([tx, ty, tx + 8 * len(label), ty + 14], fill=(255, 255, 255))
        draw.text((tx + 2, ty + 1), label, fill="black", font=font)

    if save_path is not None:
        Path(save_path).parent.mkdir(parents=True, exist_ok=True)
        img.save(save_path)

    return img
# Out:
# Images with >=1 annotation: 602

# %%
SPLIT_SEED = 42
TRAIN_FRACTION = 0.8

run_dir = PROJECT_ROOT / "runs" / f"2a_rfdetr"
split_dir = run_dir / "splits"
split_dir.mkdir(parents=True, exist_ok=True)

train_json_path = split_dir / "train_coco.json"
val_json_path   = split_dir / "val_coco.json"

rng = np.random.default_rng(SPLIT_SEED)
all_images = list(images)
rng.shuffle(all_images)

n_train = int(len(all_images) * TRAIN_FRACTION)
train_images = all_images[:n_train]
val_images   = all_images[n_train:]

train_img_ids = set(im["id"] for im in train_images)
val_img_ids   = set(im["id"] for im in val_images)

train_anns = [a for a in annotations if a["image_id"] in train_img_ids]
val_anns   = [a for a in annotations if a["image_id"] in val_img_ids]

def write_coco_subset(out_path: Path, subset_images, subset_anns, categories, coco_info=None, coco_licenses=None):
    subset = {
        "images": subset_images,
        "annotations": subset_anns,
        "categories": categories,
    }
    if coco_info is not None:
        subset["info"] = coco_info
    if coco_licenses is not None:
        subset["licenses"] = coco_licenses

    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(subset, f)
    return subset

train_subset = write_coco_subset(
    train_json_path, train_images, train_anns, categories,
    coco_info=coco.get("info"), coco_licenses=coco.get("licenses")
)
val_subset = write_coco_subset(
    val_json_path, val_images, val_anns, categories,
    coco_info=coco.get("info"), coco_licenses=coco.get("licenses")
)

print("Run dir:", run_dir)
print("Train JSON:", train_json_path, "| images:", len(train_images), "| anns:", len(train_anns))
print("Val   JSON:", val_json_path,   "| images:", len(val_images),   "| anns:", len(val_anns))

train_counts = Counter([a["category_id"] for a in train_anns]).most_common(10)
val_counts   = Counter([a["category_id"] for a in val_anns]).most_common(10)

print("\nTop-10 classes in TRAIN:")
for cid, cnt in train_counts:
    print(f"  {cat_id_to_name.get(cid, cid):<30} {cnt}")

print("\nTop-10 classes in VAL:")
for cid, cnt in val_counts:
    print(f"  {cat_id_to_name.get(cid, cid):<30} {cnt}")
# Out:
# Run dir: /home/yukkami/cv/runs/2a_rfdetr
# Train JSON: /home/yukkami/cv/runs/2a_rfdetr/splits/train_coco.json | images: 481 | anns: 726
# Val   JSON: /home/yukkami/cv/runs/2a_rfdetr/splits/val_coco.json | images: 121 | anns: 173
#
# Top-10 classes in TRAIN:
#   No Entry (One Way)             143
#   Pedestrian Crossing            94
#   Stop                           75
#   Blind-Spot Mirror (Convex)     73
#   Turn (left/right)              53
#   No Turn (left/right)           50
#   Speed Limit                    45
#   No Stopping                    36
#   Roundabout Ahead               35
#   Give way                       27
#
# Top-10 classes in VAL:
#   No Entry (One Way)             36
#   Pedestrian Crossing            28
#   No Turn (left/right)           17
#   Stop                           17
#   Blind-Spot Mirror (Convex)     12
#   Give way                       11
#   Roundabout Ahead               10
#   Turn (left/right)              9
#   No Through Road (T-sign)       8
#   Speed Limit                    7

# %%
def normalize_coco_filenames(coco_json_path: Path, images_dir: Path) -> int:
    with open(coco_json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    updated = 0
    missing = []

    for im in data.get("images", []):
        fn = im.get("file_name", "")
        p1 = images_dir / fn
        if p1.exists():
            continue

        base = Path(fn).name
        p2 = images_dir / base
        if p2.exists():
            im["file_name"] = base
            updated += 1
        else:
            missing.append(fn)

    if missing:
        print(f"[WARN] {len(missing)} image files referenced but not found under {images_dir}")
        print("First 10 missing examples:", missing[:10])

    with open(coco_json_path, "w", encoding="utf-8") as f:
        json.dump(data, f)

    return updated

u_train = normalize_coco_filenames(train_json_path, IMAGES_DIR)
u_val   = normalize_coco_filenames(val_json_path, IMAGES_DIR)

print("Updated file_name entries -> TRAIN:", u_train, "| VAL:", u_val)

with open(train_json_path, "r", encoding="utf-8") as f:
    _train = json.load(f)
print("Example train file_names:", [im["file_name"] for im in _train["images"][:5]])

sorted_cat_ids = sorted([c["id"] for c in categories])
coco_cat_id_to_contig = {cid: i + 1 for i, cid in enumerate(sorted_cat_ids)}
contig_to_name = {i + 1: cat_id_to_name[cid] for i, cid in enumerate(sorted_cat_ids)}
NUM_CLASSES = len(sorted_cat_ids) + 1

print("NUM_CLASSES (incl background):", NUM_CLASSES)
print("Example mapping COCO->contig:", list(coco_cat_id_to_contig.items())[:5])
# Out:
# Updated file_name entries -> TRAIN: 481 | VAL: 121
# Example train file_names: ['24b674c2-Pre_2026_6609.jpg', 'c89e8b4a-IMG_1368.jpg', '89530c81-IMG_20251125_194913.jpg', 'bd271b5d-IMG_1401.jpg', 'f09e9bf4-Pre_2026_6657.jpg']
# NUM_CLASSES (incl background): 39
# Example mapping COCO->contig: [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)]

# %%
import os
import json
import shutil
import tempfile
from pathlib import Path

os.environ["TMPDIR"] = "/tmp"
os.environ["TMP"]    = "/tmp"
os.environ["TEMP"]   = "/tmp"
tempfile.tempdir     = "/tmp"

rfdetr_root = run_dir / "rfdetr_data"
rfdetr_train = rfdetr_root / "train"
rfdetr_valid = rfdetr_root / "valid"
rfdetr_test  = rfdetr_root / "test"

for p in [rfdetr_train, rfdetr_valid, rfdetr_test]:
    p.mkdir(parents=True, exist_ok=True)

def _safe_link_or_copy(src: Path, dst: Path):
    dst.parent.mkdir(parents=True, exist_ok=True)
    if dst.exists():
        return
    try:
        os.symlink(src.resolve(), dst)
    except Exception:
        shutil.copy2(src, dst)

def _materialize_split(split_json_path: Path, out_dir: Path):
    ann_out = out_dir / "_annotations.coco.json"
    shutil.copy2(split_json_path, ann_out)

    with open(split_json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    missing = 0
    for im in data.get("images", []):
        fn = im["file_name"]
        src = IMAGES_DIR / fn
        if not src.exists():
            src = IMAGES_DIR / Path(fn).name
        if not src.exists():
            missing += 1
            continue
        dst = out_dir / Path(src).name
        _safe_link_or_copy(src, dst)

    return len(data.get("images", [])), missing

n_tr, miss_tr = _materialize_split(train_json_path, rfdetr_train)
n_va, miss_va = _materialize_split(val_json_path, rfdetr_valid)
n_te, miss_te = _materialize_split(val_json_path, rfdetr_test)

print("RF-DETR dataset created at:", rfdetr_root)
print(f"  train: {n_tr} images | missing on disk: {miss_tr}")
print(f"  valid: {n_va} images | missing on disk: {miss_va}")
print(f"  test : {n_te} images | missing on disk: {miss_te}")
# Out:
# RF-DETR dataset created at: /home/yukkami/cv/runs/2a_rfdetr/rfdetr_data
#   train: 481 images | missing on disk: 0
#   valid: 121 images | missing on disk: 0
#   test : 121 images | missing on disk: 0

# %% [markdown]
# ## RF-DETR training
#
# Uses `rfdetr_root/{train,valid,test}` (each split has `_annotations.coco.json` + images).
#
# Outputs go to `run_dir / "rfdetr_outputs"`.

# %%
from pathlib import Path
from importlib.metadata import version as pkg_version
from importlib.util import find_spec
import os, gc, json
import torch
import torch.nn as nn

torch.set_grad_enabled(True)
print("Autograd enabled at start of RF-DETR cell:", torch.is_grad_enabled())

os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True,max_split_size_mb:128")

if find_spec("cv2") is None:
    raise ImportError(
        "Missing module 'cv2'. This comes from OpenCV.\n"
        "Fix: ensure your environment installs opencv-python-headless.\n"
    )

def gpu_mem():
    if torch.cuda.is_available():
        free, total = torch.cuda.mem_get_info()
        return free / (1024**3), total / (1024**3)
    return None, None

def cleanup_cuda():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()

if device.type == "cuda":
    free_gb, total_gb = gpu_mem()
    print(f"GPU mem (before): free={free_gb:.2f}GB / total={total_gb:.2f}GB")
else:
    free_gb, total_gb = (None, None)

FORCE_VARIANT = None
FORCE_RES     = None

default_variant = "nano" if (device.type == "cuda" and (total_gb is not None and total_gb <= 8.5)) else "small"
default_res     = 448 if (device.type == "cuda" and (total_gb is not None and total_gb <= 8.5)) else 560

RFDETR_VARIANT = FORCE_VARIANT or default_variant
RFDETR_EPOCHS  = 15
RFDETR_LR      = 1e-4
RFDETR_RESOLUTION = FORCE_RES or default_res

if RFDETR_RESOLUTION % 56 != 0:
    raise ValueError(f"RFDETR_RESOLUTION must be divisible by 56, got {RFDETR_RESOLUTION}")

if device.type == "cuda":
    RFDETR_BATCH_SIZE = 1
    RFDETR_GRAD_ACCUM = 16
else:
    RFDETR_BATCH_SIZE = 2
    RFDETR_GRAD_ACCUM = 8

rfdetr_out = run_dir / "rfdetr_outputs"
rfdetr_out.mkdir(parents=True, exist_ok=True)

print("RF-DETR dataset_dir:", rfdetr_root)
print("RF-DETR output_dir :", rfdetr_out)
print("Requested variant  :", RFDETR_VARIANT)
print("epochs:", RFDETR_EPOCHS, "| batch_size:", RFDETR_BATCH_SIZE, "| grad_accum:", RFDETR_GRAD_ACCUM)
print("lr:", RFDETR_LR, "| resolution:", RFDETR_RESOLUTION)

def ensure_supercategory_in_coco_json(coco_path: Path, default_supercategory: str = "sign") -> int:
    if not coco_path.exists():
        return 0
    with open(coco_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    cats = data.get("categories", [])
    if not isinstance(cats, list):
        return 0

    changed = 0
    for c in cats:
        if isinstance(c, dict) and "supercategory" not in c:
            name = str(c.get("name", "")).strip().lower()
            c["supercategory"] = "none" if name == "none" else default_supercategory
            changed += 1

    if changed:
        with open(coco_path, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

    return changed

anno_files = [
    Path(rfdetr_root) / "train" / "_annotations.coco.json",
    Path(rfdetr_root) / "valid" / "_annotations.coco.json",
    Path(rfdetr_root) / "test"  / "_annotations.coco.json",
]
for p in anno_files:
    c = ensure_supercategory_in_coco_json(p, default_supercategory="sign")
    print(f"{'Patched' if c else 'OK'} {p} ({c} changes)")

try:
    import rfdetr
    print("Installed rfdetr version:", pkg_version("rfdetr"))
except Exception as e:
    raise ImportError("Failed to import rfdetr.\n" f"Original error: {repr(e)}")

available = sorted([n for n in dir(rfdetr) if n.startswith("RFDETR")])
print("RFDETR symbols available:", available)

variant_to_classname = {
    "nano": "RFDETRNano",
    "small": "RFDETRSmall",
    "base": "RFDETRBase",
    "medium": "RFDETRMedium",
    "large": "RFDETRLarge",
    "xlarge": "RFDETRXLarge",
    "2xlarge": "RFDETR2XLarge",
}

def safe_enable_grad_checkpointing(root_obj) -> bool:
    import functools
    from torch.utils.checkpoint import checkpoint as torch_checkpoint

    try:
        ckpt_fn = functools.partial(torch_checkpoint, use_reentrant=False)
    except TypeError:
        ckpt_fn = torch_checkpoint

    enabled = False
    seen = set()
    stack = [root_obj]

    def patch_module(m: nn.Module):
        nonlocal enabled

        if hasattr(m, "gradient_checkpointing_enable"):
            try:
                m.gradient_checkpointing_enable()
                enabled = True
            except Exception:
                pass

        for sub in m.modules():
            if hasattr(sub, "gradient_checkpointing"):
                try:
                    setattr(sub, "gradient_checkpointing", True)
                    enabled = True
                except Exception:
                    pass

                try:
                    if getattr(sub, "gradient_checkpointing", False) and not hasattr(sub, "_gradient_checkpointing_func"):
                        setattr(sub, "_gradient_checkpointing_func", ckpt_fn)
                        enabled = True
                except Exception:
                    pass

    while stack:
        x = stack.pop()
        xid = id(x)
        if xid in seen:
            continue
        seen.add(xid)

        if isinstance(x, nn.Module):
            patch_module(x)
            continue

        for attr in ("model", "module", "net", "backbone", "encoder", "transformer"):
            if hasattr(x, attr):
                try:
                    v = getattr(x, attr)
                    if v is not None:
                        stack.append(v)
                except Exception:
                    pass

        if hasattr(x, "__dict__"):
            for v in list(x.__dict__.values())[:80]:
                if isinstance(v, nn.Module):
                    stack.append(v)
                elif hasattr(v, "__dict__"):
                    stack.append(v)

    return enabled

attempts = [
    (RFDETR_VARIANT, RFDETR_RESOLUTION, RFDETR_BATCH_SIZE, RFDETR_GRAD_ACCUM),
    ("nano", 448, 1, 16),
    ("nano", 392, 1, 16),
    ("nano", 336, 1, 16),
]

last_err = None

for (variant, res, bs, accum) in attempts:
    if res % 56 != 0:
        continue

    print("\n==============================")
    print(f"Attempt: variant={variant} | res={res} | batch={bs} | grad_accum={accum}")
    print("==============================")

    cleanup_cuda()
    if device.type == "cuda":
        free_gb, total_gb = gpu_mem()
        print(f"GPU mem (pre-attempt): free={free_gb:.2f}GB / total={total_gb:.2f}GB")

    cname = variant_to_classname.get(variant.lower())
    if cname is None or not hasattr(rfdetr, cname):
        print(f"Skipping: class for variant '{variant}' not available")
        continue

    try:
        torch.set_grad_enabled(True)
        print("Autograd enabled pre-train:", torch.is_grad_enabled())

        rfdetr_model = getattr(rfdetr, cname)()

        ckpt_on = safe_enable_grad_checkpointing(rfdetr_model)
        print("Gradient checkpointing enabled (safe):", ckpt_on)

        with torch.enable_grad():
            rfdetr_model.train(
                dataset_dir=str(rfdetr_root),
                output_dir=str(rfdetr_out),
                epochs=RFDETR_EPOCHS,
                batch_size=bs,
                grad_accum_steps=accum,
                lr=RFDETR_LR,
                resolution=res,
                early_stopping=True,
            )

        print("\nRF-DETR training finished.")
        print("Artifacts saved to:", rfdetr_out)
        break

    except torch.cuda.OutOfMemoryError as e:
        last_err = e
        print("\nCUDA OOM on this attempt.")
        print("Error:", repr(e))
        try:
            del rfdetr_model
        except Exception:
            pass
        cleanup_cuda()
        continue

    except Exception:
        raise

else:
    raise RuntimeError(
        "All RF-DETR attempts failed due to CUDA OOM.\n"
        "Next steps: close other GPU processes (nvidia-smi), or train on CPU.\n"
        f"Last error: {repr(last_err)}"
    )
# Out:
# Autograd enabled at start of RF-DETR cell: True
# GPU mem (before): free=6.27GB / total=7.77GB
# RF-DETR dataset_dir: /home/yukkami/cv/runs/2a_rfdetr/rfdetr_data
# RF-DETR output_dir : /home/yukkami/cv/runs/2a_rfdetr/rfdetr_outputs
# Requested variant  : nano
# epochs: 15 | batch_size: 1 | grad_accum: 16
# lr: 0.0001 | resolution: 448
# Patched /home/yukkami/cv/runs/2a_rfdetr/rfdetr_data/train/_annotations.coco.json (38 changes)
# Patched /home/yukkami/cv/runs/2a_rfdetr/rfdetr_data/valid/_annotations.coco.json (38 changes)
# Patched /home/yukkami/cv/runs/2a_rfdetr/rfdetr_data/test/_annotations.coco.json (38 changes)
# Installed rfdetr version: 1.4.0.post0
# RFDETR symbols available: ['RFDETR2XLarge', 'RFDETRBase', 'RFDETRLarge', 'RFDETRLargeDeprecated', 'RFDETRMedium', 'RFDETRNano', 'RFDETRSeg2XLarge', 'RFDETRSegLarge', 'RFDETRSegMedium', 'RFDETRSegNano', 'RFDETRSegPreview', 'RFDETRSegSmall', 'RFDETRSegXLarge', 'RFDETRSmall', 'RFDETRXLarge']
#
# ==============================
# Attempt: variant=nano | res=448 | batch=1 | grad_accum=16
# ==============================
# GPU mem (pre-attempt): free=6.26GB / total=7.77GB
# Autograd enabled pre-train: True
# rf-detr-nano.pth: 100%|██████████| 349M/349M [00:10<00:00, 36.3MiB/s]
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# Gradient checkpointing enabled (safe): True
# Unable to initialize TensorBoard. Logging is turned off for this session.  Run 'pip install tensorboard' to enable logging.
# Not using distributed mode
# git:
#   sha: b12c2d4d09aa8a3e659c737a0603c2bf976ef99d, status: has uncommited changes, branch: andrew
#
# Namespace(num_classes=39, grad_accum_steps=16, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=1, weight_decay=0.0001, epochs=15, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-nano.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=2, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/home/yukkami/cv/runs/2a_rfdetr/rfdetr_data', square_resize_div_64=True, output_dir='/home/yukkami/cv/runs/2a_rfdetr/rfdetr_outputs', dont_save_weights=False, checkpoint_interval=10, seed=42, resume=None, start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=448, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=24, mask_downsample_ratio=4, license='Apache-2.0', tensorboard=True, wandb=False, project=None, run=None, class_names=['Animal', 'Back', 'Blind-Spot Mirror (Convex)', 'Bump', 'Circular', 'Damaged', 'Front', 'Give way', 'Good', 'Heavily Damaged', 'Maximum Height', 'No Entry (One Way)', 'No Parking', 'No Stopping', 'No Through Road (T-sign)', 'No Turn (left/right)', 'No U-turn', 'No Waiting', 'Octagonal', 'Parking', 'Pedestrian Crossing', 'Pole-mounted', 'Priority To/Over Oncoming Vehicles', 'Road Narrows', 'Roadworks', 'Roundabout Ahead', 'Side', 'Speed Limit', 'Square', 'Stop', 'Traffic Light', 'Triangular', 'Turn (left/right)', 'Two Way', 'Two-way traffic', 'Uneven Road', 'Wall-mounted', 'Weathered'], run_test=True, segmentation_head=False, eval_max_dets=500, distributed=False)
# number of params: 30280202
# [608]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [608]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [608]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  16
# Total batch size:  16
# LENGTH OF DATA LOADER: 30
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Epoch: [0]  [ 0/30]  eta: 0:03:20  lr: 0.000100  class_error: 100.00  loss: 30.1420 (30.1420)  loss_ce: 9.9995 (9.9995)  loss_bbox: 0.0396 (0.0396)  loss_giou: 0.0468 (0.0468)  loss_ce_0: 9.5829 (9.5829)  loss_bbox_0: 0.0960 (0.0960)  loss_giou_0: 0.0917 (0.0917)  loss_ce_enc: 9.7588 (9.7588)  loss_bbox_enc: 0.2578 (0.2578)  loss_giou_enc: 0.2690 (0.2690)  loss_ce_unscaled: 9.9995 (9.9995)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.0079 (0.0079)  loss_giou_unscaled: 0.0234 (0.0234)  cardinality_error_unscaled: 3899.0000 (3899.0000)  loss_ce_0_unscaled: 9.5829 (9.5829)  loss_bbox_0_unscaled: 0.0192 (0.0192)  loss_giou_0_unscaled: 0.0458 (0.0458)  cardinality_error_0_unscaled: 3898.0000 (3898.0000)  loss_ce_enc_unscaled: 9.7588 (9.7588)  loss_bbox_enc_unscaled: 0.0516 (0.0516)  loss_giou_enc_unscaled: 0.1345 (0.1345)  cardinality_error_enc_unscaled: 3899.0000 (3899.0000)  time: 6.6939  data: 2.6894  max mem: 801
# Epoch: [0]  [10/30]  eta: 0:01:09  lr: 0.000100  class_error: 66.67  loss: 5.9212 (8.2476)  loss_ce: 1.2683 (2.0536)  loss_bbox: 0.1280 (0.2669)  loss_giou: 0.2879 (0.3197)  loss_ce_0: 1.3701 (2.0501)  loss_bbox_0: 0.1253 (0.3132)  loss_giou_0: 0.2178 (0.3342)  loss_ce_enc: 1.2747 (2.0137)  loss_bbox_enc: 0.2578 (0.4249)  loss_giou_enc: 0.5187 (0.4713)  loss_ce_unscaled: 1.2683 (2.0536)  class_error_unscaled: 100.0000 (86.8298)  loss_bbox_unscaled: 0.0256 (0.0534)  loss_giou_unscaled: 0.1439 (0.1599)  cardinality_error_unscaled: 3899.0000 (3896.7273)  loss_ce_0_unscaled: 1.3701 (2.0501)  loss_bbox_0_unscaled: 0.0251 (0.0626)  loss_giou_0_unscaled: 0.1089 (0.1671)  cardinality_error_0_unscaled: 3898.0000 (3896.1818)  loss_ce_enc_unscaled: 1.2747 (2.0137)  loss_bbox_enc_unscaled: 0.0516 (0.0850)  loss_giou_enc_unscaled: 0.2594 (0.2357)  cardinality_error_enc_unscaled: 3899.0000 (3897.6364)  time: 3.4794  data: 0.2672  max mem: 1069
# Epoch: [0]  [20/30]  eta: 0:00:32  lr: 0.000100  class_error: 100.00  loss: 5.4561 (6.9298)  loss_ce: 1.2683 (1.7218)  loss_bbox: 0.0799 (0.2372)  loss_giou: 0.0868 (0.2363)  loss_ce_0: 1.3710 (1.7732)  loss_bbox_0: 0.1042 (0.2464)  loss_giou_0: 0.1056 (0.2416)  loss_ce_enc: 1.2904 (1.6793)  loss_bbox_enc: 0.3375 (0.3892)  loss_giou_enc: 0.3276 (0.4047)  loss_ce_unscaled: 1.2683 (1.7218)  class_error_unscaled: 100.0000 (78.8156)  loss_bbox_unscaled: 0.0160 (0.0474)  loss_giou_unscaled: 0.0434 (0.1182)  cardinality_error_unscaled: 3899.0000 (3897.8095)  loss_ce_0_unscaled: 1.3710 (1.7732)  loss_bbox_0_unscaled: 0.0208 (0.0493)  loss_giou_0_unscaled: 0.0528 (0.1208)  cardinality_error_0_unscaled: 3899.0000 (3897.1429)  loss_ce_enc_unscaled: 1.2904 (1.6793)  loss_bbox_enc_unscaled: 0.0675 (0.0778)  loss_giou_enc_unscaled: 0.1638 (0.2024)  cardinality_error_enc_unscaled: 3899.0000 (3898.2857)  time: 3.1119  data: 0.0245  max mem: 1091
# Epoch: [0]  [29/30]  eta: 0:00:03  lr: 0.000100  class_error: 92.31  loss: 4.9117 (6.1504)  loss_ce: 1.1943 (1.5297)  loss_bbox: 0.0799 (0.2050)  loss_giou: 0.0868 (0.2091)  loss_ce_0: 1.3158 (1.5801)  loss_bbox_0: 0.1050 (0.2107)  loss_giou_0: 0.1283 (0.2125)  loss_ce_enc: 1.2638 (1.5159)  loss_bbox_enc: 0.2386 (0.3321)  loss_giou_enc: 0.2523 (0.3552)  loss_ce_unscaled: 1.1943 (1.5297)  class_error_unscaled: 100.0000 (78.0940)  loss_bbox_unscaled: 0.0160 (0.0410)  loss_giou_unscaled: 0.0434 (0.1046)  cardinality_error_unscaled: 3899.0000 (3898.0000)  loss_ce_0_unscaled: 1.3158 (1.5801)  loss_bbox_0_unscaled: 0.0210 (0.0421)  loss_giou_0_unscaled: 0.0641 (0.1063)  cardinality_error_0_unscaled: 3899.0000 (3897.5333)  loss_ce_enc_unscaled: 1.2638 (1.5159)  loss_bbox_enc_unscaled: 0.0477 (0.0664)  loss_giou_enc_unscaled: 0.1262 (0.1776)  cardinality_error_enc_unscaled: 3899.0000 (3898.3333)  time: 2.9531  data: 0.0230  max mem: 1091
# Epoch: [0] Total time: 0:01:33 (3.1248 s / it)
# Averaged stats: lr: 0.000100  class_error: 92.31  loss: 4.9117 (6.1504)  loss_ce: 1.1943 (1.5297)  loss_bbox: 0.0799 (0.2050)  loss_giou: 0.0868 (0.2091)  loss_ce_0: 1.3158 (1.5801)  loss_bbox_0: 0.1050 (0.2107)  loss_giou_0: 0.1283 (0.2125)  loss_ce_enc: 1.2638 (1.5159)  loss_bbox_enc: 0.2386 (0.3321)  loss_giou_enc: 0.2523 (0.3552)  loss_ce_unscaled: 1.1943 (1.5297)  class_error_unscaled: 100.0000 (78.0940)  loss_bbox_unscaled: 0.0160 (0.0410)  loss_giou_unscaled: 0.0434 (0.1046)  cardinality_error_unscaled: 3899.0000 (3898.0000)  loss_ce_0_unscaled: 1.3158 (1.5801)  loss_bbox_0_unscaled: 0.0210 (0.0421)  loss_giou_0_unscaled: 0.0641 (0.1063)  cardinality_error_0_unscaled: 3899.0000 (3897.5333)  loss_ce_enc_unscaled: 1.2638 (1.5159)  loss_bbox_enc_unscaled: 0.0477 (0.0664)  loss_giou_enc_unscaled: 0.1262 (0.1776)  cardinality_error_enc_unscaled: 3899.0000 (3898.3333)
# Test:  [  0/121]  eta: 0:00:46  class_error: 50.00  loss: 4.1929 (4.1929)  loss_ce: 1.2031 (1.2031)  loss_bbox: 0.0295 (0.0295)  loss_giou: 0.0768 (0.0768)  loss_ce_0: 1.2734 (1.2734)  loss_bbox_0: 0.0373 (0.0373)  loss_giou_0: 0.0882 (0.0882)  loss_ce_enc: 1.2031 (1.2031)  loss_bbox_enc: 0.1054 (0.1054)  loss_giou_enc: 0.1761 (0.1761)  loss_ce_unscaled: 1.2031 (1.2031)  class_error_unscaled: 50.0000 (50.0000)  loss_bbox_unscaled: 0.0059 (0.0059)  loss_giou_unscaled: 0.0384 (0.0384)  cardinality_error_unscaled: 298.0000 (298.0000)  loss_ce_0_unscaled: 1.2734 (1.2734)  loss_bbox_0_unscaled: 0.0075 (0.0075)  loss_giou_0_unscaled: 0.0441 (0.0441)  cardinality_error_0_unscaled: 298.0000 (298.0000)  loss_ce_enc_unscaled: 1.2031 (1.2031)  loss_bbox_enc_unscaled: 0.0211 (0.0211)  loss_giou_enc_unscaled: 0.0881 (0.0881)  cardinality_error_enc_unscaled: 298.0000 (298.0000)  time: 0.3838  data: 0.2965  max mem: 1091
# Test:  [ 10/121]  eta: 0:00:13  class_error: 50.00  loss: 4.3730 (4.4479)  loss_ce: 1.1484 (1.1690)  loss_bbox: 0.0673 (0.0855)  loss_giou: 0.1226 (0.1917)  loss_ce_0: 1.2734 (1.2102)  loss_bbox_0: 0.0605 (0.0824)  loss_giou_0: 0.1319 (0.1895)  loss_ce_enc: 1.2031 (1.1960)  loss_bbox_enc: 0.1019 (0.1057)  loss_giou_enc: 0.1761 (0.2177)  loss_ce_unscaled: 1.1484 (1.1690)  class_error_unscaled: 100.0000 (71.2121)  loss_bbox_unscaled: 0.0135 (0.0171)  loss_giou_unscaled: 0.0613 (0.0959)  cardinality_error_unscaled: 298.0000 (297.9091)  loss_ce_0_unscaled: 1.2734 (1.2102)  loss_bbox_0_unscaled: 0.0121 (0.0165)  loss_giou_0_unscaled: 0.0659 (0.0948)  cardinality_error_0_unscaled: 298.0000 (297.9091)  loss_ce_enc_unscaled: 1.2031 (1.1960)  loss_bbox_enc_unscaled: 0.0204 (0.0211)  loss_giou_enc_unscaled: 0.0881 (0.1089)  cardinality_error_enc_unscaled: 298.0000 (297.9091)  time: 0.1222  data: 0.0709  max mem: 1091
# Test:  [ 20/121]  eta: 0:00:09  class_error: 100.00  loss: 4.5982 (4.5900)  loss_ce: 1.1484 (1.1899)  loss_bbox: 0.0988 (0.1109)  loss_giou: 0.1752 (0.2083)  loss_ce_0: 1.2578 (1.2366)  loss_bbox_0: 0.0871 (0.1022)  loss_giou_0: 0.1734 (0.1955)  loss_ce_enc: 1.2031 (1.1955)  loss_bbox_enc: 0.0979 (0.1205)  loss_giou_enc: 0.1786 (0.2305)  loss_ce_unscaled: 1.1484 (1.1899)  class_error_unscaled: 100.0000 (64.2857)  loss_bbox_unscaled: 0.0198 (0.0222)  loss_giou_unscaled: 0.0876 (0.1041)  cardinality_error_unscaled: 298.0000 (298.2381)  loss_ce_0_unscaled: 1.2578 (1.2366)  loss_bbox_0_unscaled: 0.0174 (0.0204)  loss_giou_0_unscaled: 0.0867 (0.0978)  cardinality_error_0_unscaled: 299.0000 (298.2857)  loss_ce_enc_unscaled: 1.2031 (1.1955)  loss_bbox_enc_unscaled: 0.0196 (0.0241)  loss_giou_enc_unscaled: 0.0893 (0.1153)  cardinality_error_enc_unscaled: 298.0000 (298.1429)  time: 0.0829  data: 0.0361  max mem: 1091
# Test:  [ 30/121]  eta: 0:00:11  class_error: 100.00  loss: 4.7132 (4.4611)  loss_ce: 1.1875 (1.1633)  loss_bbox: 0.0932 (0.0992)  loss_giou: 0.1703 (0.2013)  loss_ce_0: 1.2578 (1.2355)  loss_bbox_0: 0.0757 (0.0914)  loss_giou_0: 0.1605 (0.1894)  loss_ce_enc: 1.1953 (1.1518)  loss_bbox_enc: 0.0818 (0.1078)  loss_giou_enc: 0.1783 (0.2214)  loss_ce_unscaled: 1.1875 (1.1633)  class_error_unscaled: 66.6667 (62.9032)  loss_bbox_unscaled: 0.0186 (0.0198)  loss_giou_unscaled: 0.0852 (0.1007)  cardinality_error_unscaled: 298.0000 (298.2258)  loss_ce_0_unscaled: 1.2578 (1.2355)  loss_bbox_0_unscaled: 0.0151 (0.0183)  loss_giou_0_unscaled: 0.0803 (0.0947)  cardinality_error_0_unscaled: 298.0000 (298.2258)  loss_ce_enc_unscaled: 1.1953 (1.1518)  loss_bbox_enc_unscaled: 0.0164 (0.0216)  loss_giou_enc_unscaled: 0.0892 (0.1107)  cardinality_error_enc_unscaled: 298.0000 (298.1613)  time: 0.1227  data: 0.0744  max mem: 1091
# Test:  [ 40/121]  eta: 0:00:08  class_error: 100.00  loss: 4.7132 (5.2026)  loss_ce: 1.0781 (1.1290)  loss_bbox: 0.0810 (0.2724)  loss_giou: 0.1405 (0.2801)  loss_ce_0: 1.2031 (1.2055)  loss_bbox_0: 0.0693 (0.2843)  loss_giou_0: 0.1333 (0.2787)  loss_ce_enc: 1.1797 (1.1353)  loss_bbox_enc: 0.1391 (0.3004)  loss_giou_enc: 0.1792 (0.3168)  loss_ce_unscaled: 1.0781 (1.1290)  class_error_unscaled: 100.0000 (64.6341)  loss_bbox_unscaled: 0.0162 (0.0545)  loss_giou_unscaled: 0.0702 (0.1401)  cardinality_error_unscaled: 299.0000 (298.3902)  loss_ce_0_unscaled: 1.2031 (1.2055)  loss_bbox_0_unscaled: 0.0139 (0.0569)  loss_giou_0_unscaled: 0.0667 (0.1394)  cardinality_error_0_unscaled: 299.0000 (298.3902)  loss_ce_enc_unscaled: 1.1797 (1.1353)  loss_bbox_enc_unscaled: 0.0278 (0.0601)  loss_giou_enc_unscaled: 0.0896 (0.1584)  cardinality_error_enc_unscaled: 299.0000 (298.3415)  time: 0.1237  data: 0.0733  max mem: 1091
# Test:  [ 50/121]  eta: 0:00:07  class_error: 66.67  loss: 4.9130 (5.6188)  loss_ce: 0.9531 (1.0952)  loss_bbox: 0.1551 (0.3362)  loss_giou: 0.1421 (0.3896)  loss_ce_0: 0.9766 (1.1471)  loss_bbox_0: 0.1429 (0.3643)  loss_giou_0: 0.1500 (0.4095)  loss_ce_enc: 1.0703 (1.0946)  loss_bbox_enc: 0.3417 (0.3638)  loss_giou_enc: 0.3437 (0.4184)  loss_ce_unscaled: 0.9531 (1.0952)  class_error_unscaled: 100.0000 (68.9542)  loss_bbox_unscaled: 0.0310 (0.0672)  loss_giou_unscaled: 0.0710 (0.1948)  cardinality_error_unscaled: 299.0000 (298.4510)  loss_ce_0_unscaled: 0.9766 (1.1471)  loss_bbox_0_unscaled: 0.0286 (0.0729)  loss_giou_0_unscaled: 0.0750 (0.2047)  cardinality_error_0_unscaled: 299.0000 (298.4510)  loss_ce_enc_unscaled: 1.0703 (1.0946)  loss_bbox_enc_unscaled: 0.0683 (0.0728)  loss_giou_enc_unscaled: 0.1718 (0.2092)  cardinality_error_enc_unscaled: 299.0000 (298.4118)  time: 0.0657  data: 0.0161  max mem: 1091
# Test:  [ 60/121]  eta: 0:00:05  class_error: 100.00  loss: 4.8015 (5.5564)  loss_ce: 1.1797 (1.1129)  loss_bbox: 0.0881 (0.3155)  loss_giou: 0.1126 (0.3743)  loss_ce_0: 1.2266 (1.1561)  loss_bbox_0: 0.0903 (0.3386)  loss_giou_0: 0.1169 (0.3910)  loss_ce_enc: 1.1953 (1.1090)  loss_bbox_enc: 0.1487 (0.3496)  loss_giou_enc: 0.1791 (0.4094)  loss_ce_unscaled: 1.1797 (1.1129)  class_error_unscaled: 100.0000 (72.4044)  loss_bbox_unscaled: 0.0176 (0.0631)  loss_giou_unscaled: 0.0563 (0.1872)  cardinality_error_unscaled: 299.0000 (298.4262)  loss_ce_0_unscaled: 1.2266 (1.1561)  loss_bbox_0_unscaled: 0.0181 (0.0677)  loss_giou_0_unscaled: 0.0584 (0.1955)  cardinality_error_0_unscaled: 299.0000 (298.4262)  loss_ce_enc_unscaled: 1.1953 (1.1090)  loss_bbox_enc_unscaled: 0.0297 (0.0699)  loss_giou_enc_unscaled: 0.0896 (0.2047)  cardinality_error_enc_unscaled: 299.0000 (298.3934)  time: 0.0677  data: 0.0164  max mem: 1091
# Test:  [ 70/121]  eta: 0:00:04  class_error: 0.00  loss: 4.4208 (5.5290)  loss_ce: 1.1562 (1.1043)  loss_bbox: 0.0715 (0.3141)  loss_giou: 0.1126 (0.3689)  loss_ce_0: 1.1250 (1.1319)  loss_bbox_0: 0.0661 (0.3414)  loss_giou_0: 0.1169 (0.3966)  loss_ce_enc: 1.1719 (1.1028)  loss_bbox_enc: 0.1367 (0.3573)  loss_giou_enc: 0.1948 (0.4116)  loss_ce_unscaled: 1.1562 (1.1043)  class_error_unscaled: 100.0000 (71.3615)  loss_bbox_unscaled: 0.0143 (0.0628)  loss_giou_unscaled: 0.0563 (0.1844)  cardinality_error_unscaled: 299.0000 (298.4648)  loss_ce_0_unscaled: 1.1250 (1.1319)  loss_bbox_0_unscaled: 0.0132 (0.0683)  loss_giou_0_unscaled: 0.0584 (0.1983)  cardinality_error_0_unscaled: 299.0000 (298.4648)  loss_ce_enc_unscaled: 1.1719 (1.1028)  loss_bbox_enc_unscaled: 0.0273 (0.0715)  loss_giou_enc_unscaled: 0.0974 (0.2058)  cardinality_error_enc_unscaled: 299.0000 (298.4366)  time: 0.0707  data: 0.0195  max mem: 1091
# Test:  [ 80/121]  eta: 0:00:03  class_error: 100.00  loss: 4.2944 (5.3904)  loss_ce: 1.1172 (1.0999)  loss_bbox: 0.1113 (0.2942)  loss_giou: 0.1372 (0.3449)  loss_ce_0: 0.9609 (1.1381)  loss_bbox_0: 0.0897 (0.3184)  loss_giou_0: 0.1387 (0.3692)  loss_ce_enc: 1.1172 (1.1025)  loss_bbox_enc: 0.1474 (0.3364)  loss_giou_enc: 0.1732 (0.3868)  loss_ce_unscaled: 1.1172 (1.0999)  class_error_unscaled: 50.0000 (68.1070)  loss_bbox_unscaled: 0.0223 (0.0588)  loss_giou_unscaled: 0.0686 (0.1724)  cardinality_error_unscaled: 299.0000 (298.4938)  loss_ce_0_unscaled: 0.9609 (1.1381)  loss_bbox_0_unscaled: 0.0179 (0.0637)  loss_giou_0_unscaled: 0.0694 (0.1846)  cardinality_error_0_unscaled: 299.0000 (298.4938)  loss_ce_enc_unscaled: 1.1172 (1.1025)  loss_bbox_enc_unscaled: 0.0295 (0.0673)  loss_giou_enc_unscaled: 0.0866 (0.1934)  cardinality_error_enc_unscaled: 299.0000 (298.4691)  time: 0.0652  data: 0.0178  max mem: 1091
# Test:  [ 90/121]  eta: 0:00:02  class_error: 100.00  loss: 4.6220 (5.2973)  loss_ce: 1.0859 (1.1039)  loss_bbox: 0.1208 (0.2768)  loss_giou: 0.1210 (0.3212)  loss_ce_0: 1.1250 (1.1402)  loss_bbox_0: 0.1218 (0.3010)  loss_giou_0: 0.1199 (0.3459)  loss_ce_enc: 1.1484 (1.1154)  loss_bbox_enc: 0.1474 (0.3255)  loss_giou_enc: 0.1678 (0.3674)  loss_ce_unscaled: 1.0859 (1.1039)  class_error_unscaled: 50.0000 (67.2161)  loss_bbox_unscaled: 0.0242 (0.0554)  loss_giou_unscaled: 0.0605 (0.1606)  cardinality_error_unscaled: 299.0000 (298.4725)  loss_ce_0_unscaled: 1.1250 (1.1402)  loss_bbox_0_unscaled: 0.0244 (0.0602)  loss_giou_0_unscaled: 0.0600 (0.1730)  cardinality_error_0_unscaled: 299.0000 (298.4615)  loss_ce_enc_unscaled: 1.1484 (1.1154)  loss_bbox_enc_unscaled: 0.0295 (0.0651)  loss_giou_enc_unscaled: 0.0839 (0.1837)  cardinality_error_enc_unscaled: 299.0000 (298.4505)  time: 0.0643  data: 0.0189  max mem: 1091
# Test:  [100/121]  eta: 0:00:01  class_error: 0.00  loss: 4.6369 (5.3491)  loss_ce: 1.0312 (1.0966)  loss_bbox: 0.1270 (0.3028)  loss_giou: 0.1210 (0.3250)  loss_ce_0: 1.0234 (1.1342)  loss_bbox_0: 0.1319 (0.3222)  loss_giou_0: 0.1193 (0.3448)  loss_ce_enc: 1.1172 (1.1060)  loss_bbox_enc: 0.1799 (0.3536)  loss_giou_enc: 0.1575 (0.3639)  loss_ce_unscaled: 1.0312 (1.0966)  class_error_unscaled: 50.0000 (65.5116)  loss_bbox_unscaled: 0.0254 (0.0606)  loss_giou_unscaled: 0.0605 (0.1625)  cardinality_error_unscaled: 299.0000 (298.5248)  loss_ce_0_unscaled: 1.0234 (1.1342)  loss_bbox_0_unscaled: 0.0264 (0.0644)  loss_giou_0_unscaled: 0.0597 (0.1724)  cardinality_error_0_unscaled: 299.0000 (298.5149)  loss_ce_enc_unscaled: 1.1172 (1.1060)  loss_bbox_enc_unscaled: 0.0360 (0.0707)  loss_giou_enc_unscaled: 0.0788 (0.1820)  cardinality_error_enc_unscaled: 299.0000 (298.5050)  time: 0.0619  data: 0.0175  max mem: 1091
# Test:  [110/121]  eta: 0:00:00  class_error: 100.00  loss: 4.2113 (5.5225)  loss_ce: 0.9492 (1.0797)  loss_bbox: 0.1270 (0.3528)  loss_giou: 0.1605 (0.3609)  loss_ce_0: 0.9609 (1.1158)  loss_bbox_0: 0.1319 (0.3715)  loss_giou_0: 0.1598 (0.3838)  loss_ce_enc: 0.9883 (1.0879)  loss_bbox_enc: 0.2284 (0.3780)  loss_giou_enc: 0.2103 (0.3921)  loss_ce_unscaled: 0.9492 (1.0797)  class_error_unscaled: 100.0000 (65.0150)  loss_bbox_unscaled: 0.0254 (0.0706)  loss_giou_unscaled: 0.0803 (0.1805)  cardinality_error_unscaled: 299.0000 (298.5586)  loss_ce_0_unscaled: 0.9609 (1.1158)  loss_bbox_0_unscaled: 0.0264 (0.0743)  loss_giou_0_unscaled: 0.0799 (0.1919)  cardinality_error_0_unscaled: 299.0000 (298.5495)  loss_ce_enc_unscaled: 0.9883 (1.0879)  loss_bbox_enc_unscaled: 0.0457 (0.0756)  loss_giou_enc_unscaled: 0.1052 (0.1961)  cardinality_error_enc_unscaled: 299.0000 (298.5405)  time: 0.0865  data: 0.0418  max mem: 1091
# Test:  [120/121]  eta: 0:00:00  class_error: 100.00  loss: 9.2595 (5.8449)  loss_ce: 0.8945 (1.0660)  loss_bbox: 1.1236 (0.4197)  loss_giou: 0.9851 (0.4227)  loss_ce_0: 0.9570 (1.1045)  loss_bbox_0: 1.0346 (0.4366)  loss_giou_0: 0.8839 (0.4324)  loss_ce_enc: 1.0156 (1.0781)  loss_bbox_enc: 0.7385 (0.4477)  loss_giou_enc: 0.7944 (0.4372)  loss_ce_unscaled: 0.8945 (1.0660)  class_error_unscaled: 100.0000 (66.6667)  loss_bbox_unscaled: 0.2247 (0.0839)  loss_giou_unscaled: 0.4925 (0.2113)  cardinality_error_unscaled: 299.0000 (298.5620)  loss_ce_0_unscaled: 0.9570 (1.1045)  loss_bbox_0_unscaled: 0.2069 (0.0873)  loss_giou_0_unscaled: 0.4420 (0.2162)  cardinality_error_0_unscaled: 299.0000 (298.5537)  loss_ce_enc_unscaled: 1.0156 (1.0781)  loss_bbox_enc_unscaled: 0.1477 (0.0895)  loss_giou_enc_unscaled: 0.3972 (0.2186)  cardinality_error_enc_unscaled: 299.0000 (298.5455)  time: 0.1257  data: 0.0644  max mem: 1091
# Test: Total time: 0:00:11 (0.0910 s / it)
# Averaged stats: class_error: 100.00  loss: 9.2595 (5.8449)  loss_ce: 0.8945 (1.0660)  loss_bbox: 1.1236 (0.4197)  loss_giou: 0.9851 (0.4227)  loss_ce_0: 0.9570 (1.1045)  loss_bbox_0: 1.0346 (0.4366)  loss_giou_0: 0.8839 (0.4324)  loss_ce_enc: 1.0156 (1.0781)  loss_bbox_enc: 0.7385 (0.4477)  loss_giou_enc: 0.7944 (0.4372)  loss_ce_unscaled: 0.8945 (1.0660)  class_error_unscaled: 100.0000 (66.6667)  loss_bbox_unscaled: 0.2247 (0.0839)  loss_giou_unscaled: 0.4925 (0.2113)  cardinality_error_unscaled: 299.0000 (298.5620)  loss_ce_0_unscaled: 0.9570 (1.1045)  loss_bbox_0_unscaled: 0.2069 (0.0873)  loss_giou_0_unscaled: 0.4420 (0.2162)  cardinality_error_0_unscaled: 299.0000 (298.5537)  loss_ce_enc_unscaled: 1.0156 (1.0781)  loss_bbox_enc_unscaled: 0.1477 (0.0895)  loss_giou_enc_unscaled: 0.3972 (0.2186)  cardinality_error_enc_unscaled: 299.0000 (298.5455)
# Accumulating evaluation results...
# DONE (t=0.23s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.125
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.135
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.529
# RuntimeWarning: Mean of empty slice
# RuntimeWarning: Mean of empty slice
# RuntimeWarning: Mean of empty slice
# Test:  [  0/121]  eta: 0:00:44  class_error: 50.00  loss: 4.1915 (4.1915)  loss_ce: 1.1953 (1.1953)  loss_bbox: 0.0280 (0.0280)  loss_giou: 0.0730 (0.0730)  loss_ce_0: 1.2812 (1.2812)  loss_bbox_0: 0.0358 (0.0358)  loss_giou_0: 0.0866 (0.0866)  loss_ce_enc: 1.1953 (1.1953)  loss_bbox_enc: 0.1120 (0.1120)  loss_giou_enc: 0.1842 (0.1842)  loss_ce_unscaled: 1.1953 (1.1953)  class_error_unscaled: 50.0000 (50.0000)  loss_bbox_unscaled: 0.0056 (0.0056)  loss_giou_unscaled: 0.0365 (0.0365)  cardinality_error_unscaled: 298.0000 (298.0000)  loss_ce_0_unscaled: 1.2812 (1.2812)  loss_bbox_0_unscaled: 0.0072 (0.0072)  loss_giou_0_unscaled: 0.0433 (0.0433)  cardinality_error_0_unscaled: 298.0000 (298.0000)  loss_ce_enc_unscaled: 1.1953 (1.1953)  loss_bbox_enc_unscaled: 0.0224 (0.0224)  loss_giou_enc_unscaled: 0.0921 (0.0921)  cardinality_error_enc_unscaled: 298.0000 (298.0000)  time: 0.3667  data: 0.2978  max mem: 1091
# Test:  [ 10/121]  eta: 0:00:15  class_error: 50.00  loss: 4.3804 (4.4601)  loss_ce: 1.1484 (1.1726)  loss_bbox: 0.0689 (0.0847)  loss_giou: 0.1186 (0.1892)  loss_ce_0: 1.2812 (1.2188)  loss_bbox_0: 0.0624 (0.0829)  loss_giou_0: 0.1254 (0.1879)  loss_ce_enc: 1.2109 (1.1982)  loss_bbox_enc: 0.1005 (0.1067)  loss_giou_enc: 0.1842 (0.2193)  loss_ce_unscaled: 1.1484 (1.1726)  class_error_unscaled: 100.0000 (71.2121)  loss_bbox_unscaled: 0.0138 (0.0169)  loss_giou_unscaled: 0.0593 (0.0946)  cardinality_error_unscaled: 298.0000 (297.9091)  loss_ce_0_unscaled: 1.2812 (1.2188)  loss_bbox_0_unscaled: 0.0125 (0.0166)  loss_giou_0_unscaled: 0.0627 (0.0939)  cardinality_error_0_unscaled: 298.0000 (297.9091)  loss_ce_enc_unscaled: 1.2109 (1.1982)  loss_bbox_enc_unscaled: 0.0201 (0.0213)  loss_giou_enc_unscaled: 0.0921 (0.1097)  cardinality_error_enc_unscaled: 298.0000 (297.9091)  time: 0.1426  data: 0.0773  max mem: 1190
# Test:  [ 20/121]  eta: 0:00:11  class_error: 100.00  loss: 4.6249 (4.5973)  loss_ce: 1.1484 (1.1935)  loss_bbox: 0.0982 (0.1115)  loss_giou: 0.1719 (0.2082)  loss_ce_0: 1.2734 (1.2383)  loss_bbox_0: 0.0974 (0.1036)  loss_giou_0: 0.1723 (0.1969)  loss_ce_enc: 1.2500 (1.2041)  loss_bbox_enc: 0.0999 (0.1152)  loss_giou_enc: 0.1955 (0.2261)  loss_ce_unscaled: 1.1484 (1.1935)  class_error_unscaled: 100.0000 (64.2857)  loss_bbox_unscaled: 0.0196 (0.0223)  loss_giou_unscaled: 0.0859 (0.1041)  cardinality_error_unscaled: 298.0000 (298.2381)  loss_ce_0_unscaled: 1.2734 (1.2383)  loss_bbox_0_unscaled: 0.0195 (0.0207)  loss_giou_0_unscaled: 0.0862 (0.0985)  cardinality_error_0_unscaled: 298.0000 (298.2381)  loss_ce_enc_unscaled: 1.2500 (1.2041)  loss_bbox_enc_unscaled: 0.0200 (0.0230)  loss_giou_enc_unscaled: 0.0978 (0.1131)  cardinality_error_enc_unscaled: 298.0000 (298.1429)  time: 0.1034  data: 0.0416  max mem: 1198
# Test:  [ 30/121]  eta: 0:00:12  class_error: 100.00  loss: 4.7094 (4.4644)  loss_ce: 1.1875 (1.1658)  loss_bbox: 0.0923 (0.0995)  loss_giou: 0.1719 (0.2010)  loss_ce_0: 1.2734 (1.2345)  loss_bbox_0: 0.0735 (0.0921)  loss_giou_0: 0.1612 (0.1889)  loss_ce_enc: 1.2188 (1.1590)  loss_bbox_enc: 0.0886 (0.1044)  loss_giou_enc: 0.1975 (0.2192)  loss_ce_unscaled: 1.1875 (1.1658)  class_error_unscaled: 66.6667 (62.9032)  loss_bbox_unscaled: 0.0185 (0.0199)  loss_giou_unscaled: 0.0859 (0.1005)  cardinality_error_unscaled: 298.0000 (298.2258)  loss_ce_0_unscaled: 1.2734 (1.2345)  loss_bbox_0_unscaled: 0.0147 (0.0184)  loss_giou_0_unscaled: 0.0806 (0.0945)  cardinality_error_0_unscaled: 298.0000 (298.2258)  loss_ce_enc_unscaled: 1.2188 (1.1590)  loss_bbox_enc_unscaled: 0.0177 (0.0209)  loss_giou_enc_unscaled: 0.0987 (0.1096)  cardinality_error_enc_unscaled: 298.0000 (298.1613)  time: 0.1335  data: 0.0781  max mem: 1198
# Test:  [ 40/121]  eta: 0:00:09  class_error: 100.00  loss: 4.7094 (5.1811)  loss_ce: 1.0781 (1.1381)  loss_bbox: 0.0806 (0.2561)  loss_giou: 0.1396 (0.2709)  loss_ce_0: 1.1953 (1.2068)  loss_bbox_0: 0.0727 (0.2784)  loss_giou_0: 0.1369 (0.2767)  loss_ce_enc: 1.1875 (1.1379)  loss_bbox_enc: 0.1499 (0.2996)  loss_giou_enc: 0.1934 (0.3166)  loss_ce_unscaled: 1.0781 (1.1381)  class_error_unscaled: 100.0000 (62.1951)  loss_bbox_unscaled: 0.0161 (0.0512)  loss_giou_unscaled: 0.0698 (0.1354)  cardinality_error_unscaled: 299.0000 (298.3902)  loss_ce_0_unscaled: 1.1953 (1.2068)  loss_bbox_0_unscaled: 0.0145 (0.0557)  loss_giou_0_unscaled: 0.0685 (0.1383)  cardinality_error_0_unscaled: 299.0000 (298.3902)  loss_ce_enc_unscaled: 1.1875 (1.1379)  loss_bbox_enc_unscaled: 0.0300 (0.0599)  loss_giou_enc_unscaled: 0.0967 (0.1583)  cardinality_error_enc_unscaled: 299.0000 (298.3415)  time: 0.1285  data: 0.0758  max mem: 1201
# Test:  [ 50/121]  eta: 0:00:07  class_error: 66.67  loss: 4.9003 (5.5882)  loss_ce: 1.0312 (1.0969)  loss_bbox: 0.1601 (0.3140)  loss_giou: 0.1476 (0.3844)  loss_ce_0: 0.9961 (1.1501)  loss_bbox_0: 0.1529 (0.3574)  loss_giou_0: 0.1550 (0.4040)  loss_ce_enc: 1.0781 (1.0979)  loss_bbox_enc: 0.3436 (0.3652)  loss_giou_enc: 0.3506 (0.4182)  loss_ce_unscaled: 1.0312 (1.0969)  class_error_unscaled: 100.0000 (66.9935)  loss_bbox_unscaled: 0.0320 (0.0628)  loss_giou_unscaled: 0.0738 (0.1922)  cardinality_error_unscaled: 299.0000 (298.4510)  loss_ce_0_unscaled: 0.9961 (1.1501)  loss_bbox_0_unscaled: 0.0306 (0.0715)  loss_giou_0_unscaled: 0.0775 (0.2020)  cardinality_error_0_unscaled: 299.0000 (298.4314)  loss_ce_enc_unscaled: 1.0781 (1.0979)  loss_bbox_enc_unscaled: 0.0687 (0.0730)  loss_giou_enc_unscaled: 0.1753 (0.2091)  cardinality_error_enc_unscaled: 299.0000 (298.4118)  time: 0.0742  data: 0.0215  max mem: 1202
# Test:  [ 60/121]  eta: 0:00:06  class_error: 100.00  loss: 4.7863 (5.5309)  loss_ce: 1.1797 (1.1149)  loss_bbox: 0.0893 (0.2972)  loss_giou: 0.1175 (0.3702)  loss_ce_0: 1.2344 (1.1580)  loss_bbox_0: 0.0893 (0.3321)  loss_giou_0: 0.1177 (0.3867)  loss_ce_enc: 1.2031 (1.1125)  loss_bbox_enc: 0.1467 (0.3507)  loss_giou_enc: 0.1785 (0.4087)  loss_ce_unscaled: 1.1797 (1.1149)  class_error_unscaled: 100.0000 (70.7650)  loss_bbox_unscaled: 0.0179 (0.0594)  loss_giou_unscaled: 0.0587 (0.1851)  cardinality_error_unscaled: 299.0000 (298.4262)  loss_ce_0_unscaled: 1.2344 (1.1580)  loss_bbox_0_unscaled: 0.0179 (0.0664)  loss_giou_0_unscaled: 0.0588 (0.1933)  cardinality_error_0_unscaled: 299.0000 (298.4098)  loss_ce_enc_unscaled: 1.2031 (1.1125)  loss_bbox_enc_unscaled: 0.0293 (0.0701)  loss_giou_enc_unscaled: 0.0892 (0.2043)  cardinality_error_enc_unscaled: 299.0000 (298.3934)  time: 0.0790  data: 0.0255  max mem: 1203
# Test:  [ 70/121]  eta: 0:00:05  class_error: 0.00  loss: 4.4781 (5.5154)  loss_ce: 1.1562 (1.1066)  loss_bbox: 0.0695 (0.2987)  loss_giou: 0.1175 (0.3651)  loss_ce_0: 1.1328 (1.1354)  loss_bbox_0: 0.0669 (0.3392)  loss_giou_0: 0.1177 (0.3908)  loss_ce_enc: 1.1797 (1.1044)  loss_bbox_enc: 0.1353 (0.3614)  loss_giou_enc: 0.1997 (0.4137)  loss_ce_unscaled: 1.1562 (1.1066)  class_error_unscaled: 100.0000 (69.9531)  loss_bbox_unscaled: 0.0139 (0.0597)  loss_giou_unscaled: 0.0587 (0.1826)  cardinality_error_unscaled: 299.0000 (298.4648)  loss_ce_0_unscaled: 1.1328 (1.1354)  loss_bbox_0_unscaled: 0.0134 (0.0678)  loss_giou_0_unscaled: 0.0588 (0.1954)  cardinality_error_0_unscaled: 299.0000 (298.4507)  loss_ce_enc_unscaled: 1.1797 (1.1044)  loss_bbox_enc_unscaled: 0.0271 (0.0723)  loss_giou_enc_unscaled: 0.0998 (0.2069)  cardinality_error_enc_unscaled: 299.0000 (298.4366)  time: 0.0833  data: 0.0292  max mem: 1203
# Test:  [ 80/121]  eta: 0:00:04  class_error: 100.00  loss: 4.2972 (5.3789)  loss_ce: 1.0781 (1.1025)  loss_bbox: 0.1123 (0.2807)  loss_giou: 0.1314 (0.3417)  loss_ce_0: 0.9805 (1.1405)  loss_bbox_0: 0.0948 (0.3164)  loss_giou_0: 0.1427 (0.3638)  loss_ce_enc: 1.1094 (1.1044)  loss_bbox_enc: 0.1563 (0.3402)  loss_giou_enc: 0.1696 (0.3885)  loss_ce_unscaled: 1.0781 (1.1025)  class_error_unscaled: 50.0000 (66.8724)  loss_bbox_unscaled: 0.0225 (0.0561)  loss_giou_unscaled: 0.0657 (0.1708)  cardinality_error_unscaled: 299.0000 (298.4938)  loss_ce_0_unscaled: 0.9805 (1.1405)  loss_bbox_0_unscaled: 0.0190 (0.0633)  loss_giou_0_unscaled: 0.0713 (0.1819)  cardinality_error_0_unscaled: 299.0000 (298.4815)  loss_ce_enc_unscaled: 1.1094 (1.1044)  loss_bbox_enc_unscaled: 0.0313 (0.0680)  loss_giou_enc_unscaled: 0.0848 (0.1942)  cardinality_error_enc_unscaled: 299.0000 (298.4691)  time: 0.0775  data: 0.0257  max mem: 1204
# Test:  [ 90/121]  eta: 0:00:03  class_error: 100.00  loss: 4.6069 (5.2911)  loss_ce: 1.0938 (1.1046)  loss_bbox: 0.1123 (0.2674)  loss_giou: 0.1187 (0.3220)  loss_ce_0: 1.1250 (1.1427)  loss_bbox_0: 0.1211 (0.2990)  loss_giou_0: 0.1210 (0.3412)  loss_ce_enc: 1.1328 (1.1172)  loss_bbox_enc: 0.1474 (0.3286)  loss_giou_enc: 0.1577 (0.3684)  loss_ce_unscaled: 1.0938 (1.1046)  class_error_unscaled: 50.0000 (66.1172)  loss_bbox_unscaled: 0.0225 (0.0535)  loss_giou_unscaled: 0.0593 (0.1610)  cardinality_error_unscaled: 299.0000 (298.4725)  loss_ce_0_unscaled: 1.1250 (1.1427)  loss_bbox_0_unscaled: 0.0242 (0.0598)  loss_giou_0_unscaled: 0.0605 (0.1706)  cardinality_error_0_unscaled: 299.0000 (298.4505)  loss_ce_enc_unscaled: 1.1328 (1.1172)  loss_bbox_enc_unscaled: 0.0295 (0.0657)  loss_giou_enc_unscaled: 0.0789 (0.1842)  cardinality_error_enc_unscaled: 299.0000 (298.4505)  time: 0.0747  data: 0.0239  max mem: 1204
# Test:  [100/121]  eta: 0:00:01  class_error: 0.00  loss: 4.6683 (5.3367)  loss_ce: 1.0391 (1.0994)  loss_bbox: 0.1275 (0.2902)  loss_giou: 0.1187 (0.3216)  loss_ce_0: 1.0391 (1.1377)  loss_bbox_0: 0.1242 (0.3192)  loss_giou_0: 0.1140 (0.3402)  loss_ce_enc: 1.1328 (1.1084)  loss_bbox_enc: 0.1809 (0.3559)  loss_giou_enc: 0.1555 (0.3640)  loss_ce_unscaled: 1.0391 (1.0994)  class_error_unscaled: 50.0000 (64.5215)  loss_bbox_unscaled: 0.0255 (0.0580)  loss_giou_unscaled: 0.0593 (0.1608)  cardinality_error_unscaled: 299.0000 (298.5248)  loss_ce_0_unscaled: 1.0391 (1.1377)  loss_bbox_0_unscaled: 0.0248 (0.0638)  loss_giou_0_unscaled: 0.0570 (0.1701)  cardinality_error_0_unscaled: 299.0000 (298.5050)  loss_ce_enc_unscaled: 1.1328 (1.1084)  loss_bbox_enc_unscaled: 0.0362 (0.0712)  loss_giou_enc_unscaled: 0.0777 (0.1820)  cardinality_error_enc_unscaled: 299.0000 (298.5050)  time: 0.0715  data: 0.0186  max mem: 1204
# Test:  [110/121]  eta: 0:00:01  class_error: 100.00  loss: 4.2513 (5.5097)  loss_ce: 0.9727 (1.0817)  loss_bbox: 0.1298 (0.3455)  loss_giou: 0.1616 (0.3628)  loss_ce_0: 1.0156 (1.1239)  loss_bbox_0: 0.1397 (0.3577)  loss_giou_0: 0.1601 (0.3744)  loss_ce_enc: 0.9883 (1.0908)  loss_bbox_enc: 0.2699 (0.3802)  loss_giou_enc: 0.2166 (0.3925)  loss_ce_unscaled: 0.9727 (1.0817)  class_error_unscaled: 100.0000 (65.0150)  loss_bbox_unscaled: 0.0260 (0.0691)  loss_giou_unscaled: 0.0808 (0.1814)  cardinality_error_unscaled: 299.0000 (298.5586)  loss_ce_0_unscaled: 1.0156 (1.1239)  loss_bbox_0_unscaled: 0.0279 (0.0715)  loss_giou_0_unscaled: 0.0800 (0.1872)  cardinality_error_0_unscaled: 299.0000 (298.5405)  loss_ce_enc_unscaled: 0.9883 (1.0908)  loss_bbox_enc_unscaled: 0.0540 (0.0760)  loss_giou_enc_unscaled: 0.1083 (0.1963)  cardinality_error_enc_unscaled: 299.0000 (298.5405)  time: 0.0931  data: 0.0401  max mem: 1204
# Test:  [120/121]  eta: 0:00:00  class_error: 100.00  loss: 9.2556 (5.8705)  loss_ce: 0.8750 (1.0646)  loss_bbox: 1.1226 (0.4375)  loss_giou: 1.0783 (0.4316)  loss_ce_0: 1.0312 (1.1082)  loss_bbox_0: 0.9379 (0.4283)  loss_giou_0: 0.9093 (0.4320)  loss_ce_enc: 1.0156 (1.0803)  loss_bbox_enc: 0.7263 (0.4483)  loss_giou_enc: 0.7986 (0.4397)  loss_ce_unscaled: 0.8750 (1.0646)  class_error_unscaled: 100.0000 (66.6667)  loss_bbox_unscaled: 0.2245 (0.0875)  loss_giou_unscaled: 0.5392 (0.2158)  cardinality_error_unscaled: 299.0000 (298.5620)  loss_ce_0_unscaled: 1.0312 (1.1082)  loss_bbox_0_unscaled: 0.1876 (0.0857)  loss_giou_0_unscaled: 0.4546 (0.2160)  cardinality_error_0_unscaled: 299.0000 (298.5455)  loss_ce_enc_unscaled: 1.0156 (1.0803)  loss_bbox_enc_unscaled: 0.1453 (0.0897)  loss_giou_enc_unscaled: 0.3993 (0.2198)  cardinality_error_enc_unscaled: 299.0000 (298.5455)  time: 0.1137  data: 0.0628  max mem: 1204
# Test: Total time: 0:00:11 (0.0985 s / it)
# Averaged stats: class_error: 100.00  loss: 9.2556 (5.8705)  loss_ce: 0.8750 (1.0646)  loss_bbox: 1.1226 (0.4375)  loss_giou: 1.0783 (0.4316)  loss_ce_0: 1.0312 (1.1082)  loss_bbox_0: 0.9379 (0.4283)  loss_giou_0: 0.9093 (0.4320)  loss_ce_enc: 1.0156 (1.0803)  loss_bbox_enc: 0.7263 (0.4483)  loss_giou_enc: 0.7986 (0.4397)  loss_ce_unscaled: 0.8750 (1.0646)  class_error_unscaled: 100.0000 (66.6667)  loss_bbox_unscaled: 0.2245 (0.0875)  loss_giou_unscaled: 0.5392 (0.2158)  cardinality_error_unscaled: 299.0000 (298.5620)  loss_ce_0_unscaled: 1.0312 (1.1082)  loss_bbox_0_unscaled: 0.1876 (0.0857)  loss_giou_0_unscaled: 0.4546 (0.2160)  cardinality_error_0_unscaled: 299.0000 (298.5455)  loss_ce_enc_unscaled: 1.0156 (1.0803)  loss_bbox_enc_unscaled: 0.1453 (0.0897)  loss_giou_enc_unscaled: 0.3993 (0.2198)  cardinality_error_enc_unscaled: 299.0000 (298.5455)
# Accumulating evaluation results...
# DONE (t=0.26s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.141
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.529
# Early stopping: Current mAP (max(regular, EMA)): 0.1247, Best: 0.0000, Diff: 0.1247, Min delta: 0.001
# Grad accum steps:  16
# Total batch size:  16
# LENGTH OF DATA LOADER: 30
# Epoch: [1]  [ 0/30]  eta: 0:02:46  lr: 0.000100  class_error: 92.31  loss: 5.7079 (5.7079)  loss_ce: 1.1427 (1.1427)  loss_bbox: 0.1205 (0.1205)  loss_giou: 0.6202 (0.6202)  loss_ce_0: 1.1504 (1.1504)  loss_bbox_0: 0.1126 (0.1126)  loss_giou_0: 0.6008 (0.6008)  loss_ce_enc: 1.0552 (1.0552)  loss_bbox_enc: 0.1760 (0.1760)  loss_giou_enc: 0.7294 (0.7294)  loss_ce_unscaled: 1.1427 (1.1427)  class_error_unscaled: 92.3077 (92.3077)  loss_bbox_unscaled: 0.0241 (0.0241)  loss_giou_unscaled: 0.3101 (0.3101)  cardinality_error_unscaled: 3897.0000 (3897.0000)  loss_ce_0_unscaled: 1.1504 (1.1504)  loss_bbox_0_unscaled: 0.0225 (0.0225)  loss_giou_0_unscaled: 0.3004 (0.3004)  cardinality_error_0_unscaled: 3897.0000 (3897.0000)  loss_ce_enc_unscaled: 1.0552 (1.0552)  loss_bbox_enc_unscaled: 0.0352 (0.0352)  loss_giou_enc_unscaled: 0.3647 (0.3647)  cardinality_error_enc_unscaled: 3897.0000 (3897.0000)  time: 5.5614  data: 2.8590  max mem: 1204
# Epoch: [1]  [10/30]  eta: 0:01:05  lr: 0.000100  class_error: 38.46  loss: 4.7124 (5.3896)  loss_ce: 0.9538 (0.9991)  loss_bbox: 0.1423 (0.3345)  loss_giou: 0.2119 (0.3728)  loss_ce_0: 1.0118 (1.0608)  loss_bbox_0: 0.1714 (0.3296)  loss_giou_0: 0.2032 (0.3626)  loss_ce_enc: 1.0552 (1.0385)  loss_bbox_enc: 0.3388 (0.4340)  loss_giou_enc: 0.2754 (0.4577)  loss_ce_unscaled: 0.9538 (0.9991)  class_error_unscaled: 50.0000 (50.0000)  loss_bbox_unscaled: 0.0285 (0.0669)  loss_giou_unscaled: 0.1059 (0.1864)  cardinality_error_unscaled: 3898.0000 (3898.1818)  loss_ce_0_unscaled: 1.0118 (1.0608)  loss_bbox_0_unscaled: 0.0343 (0.0659)  loss_giou_0_unscaled: 0.1016 (0.1813)  cardinality_error_0_unscaled: 3899.0000 (3898.3636)  loss_ce_enc_unscaled: 1.0552 (1.0385)  loss_bbox_enc_unscaled: 0.0678 (0.0868)  loss_giou_enc_unscaled: 0.1377 (0.2288)  cardinality_error_enc_unscaled: 3898.0000 (3896.4545)  time: 3.2852  data: 0.2807  max mem: 1204
# Epoch: [1]  [20/30]  eta: 0:00:30  lr: 0.000100  class_error: 100.00  loss: 4.7098 (5.4390)  loss_ce: 1.0437 (1.0860)  loss_bbox: 0.0828 (0.3650)  loss_giou: 0.1265 (0.3237)  loss_ce_0: 1.1171 (1.1120)  loss_bbox_0: 0.1350 (0.3146)  loss_giou_0: 0.1324 (0.3016)  loss_ce_enc: 1.0712 (1.0685)  loss_bbox_enc: 0.2480 (0.4605)  loss_giou_enc: 0.2754 (0.4071)  loss_ce_unscaled: 1.0437 (1.0860)  class_error_unscaled: 69.2308 (58.5714)  loss_bbox_unscaled: 0.0166 (0.0730)  loss_giou_unscaled: 0.0633 (0.1618)  cardinality_error_unscaled: 3899.0000 (3898.3810)  loss_ce_0_unscaled: 1.1171 (1.1120)  loss_bbox_0_unscaled: 0.0270 (0.0629)  loss_giou_0_unscaled: 0.0662 (0.1508)  cardinality_error_0_unscaled: 3899.0000 (3898.4286)  loss_ce_enc_unscaled: 1.0712 (1.0685)  loss_bbox_enc_unscaled: 0.0496 (0.0921)  loss_giou_enc_unscaled: 0.1377 (0.2036)  cardinality_error_enc_unscaled: 3899.0000 (3897.4762)  time: 2.9020  data: 0.0224  max mem: 1204
# Epoch: [1]  [29/30]  eta: 0:00:02  lr: 0.000100  class_error: 100.00  loss: 4.9687 (5.6577)  loss_ce: 1.0949 (1.0995)  loss_bbox: 0.0890 (0.3859)  loss_giou: 0.1265 (0.3430)  loss_ce_0: 1.1171 (1.1193)  loss_bbox_0: 0.1071 (0.3406)  loss_giou_0: 0.1413 (0.3331)  loss_ce_enc: 1.0712 (1.0785)  loss_bbox_enc: 0.2509 (0.5093)  loss_giou_enc: 0.3070 (0.4485)  loss_ce_unscaled: 1.0949 (1.0995)  class_error_unscaled: 100.0000 (62.0256)  loss_bbox_unscaled: 0.0178 (0.0772)  loss_giou_unscaled: 0.0633 (0.1715)  cardinality_error_unscaled: 3899.0000 (3893.7000)  loss_ce_0_unscaled: 1.1171 (1.1193)  loss_bbox_0_unscaled: 0.0214 (0.0681)  loss_giou_0_unscaled: 0.0706 (0.1665)  cardinality_error_0_unscaled: 3898.0000 (3893.5667)  loss_ce_enc_unscaled: 1.0712 (1.0785)  loss_bbox_enc_unscaled: 0.0502 (0.1019)  loss_giou_enc_unscaled: 0.1535 (0.2243)  cardinality_error_enc_unscaled: 3899.0000 (3891.9333)  time: 2.7187  data: 0.0221  max mem: 1204
# Epoch: [1] Total time: 0:01:27 (2.9272 s / it)
# Averaged stats: lr: 0.000100  class_error: 100.00  loss: 4.9687 (5.6577)  loss_ce: 1.0949 (1.0995)  loss_bbox: 0.0890 (0.3859)  loss_giou: 0.1265 (0.3430)  loss_ce_0: 1.1171 (1.1193)  loss_bbox_0: 0.1071 (0.3406)  loss_giou_0: 0.1413 (0.3331)  loss_ce_enc: 1.0712 (1.0785)  loss_bbox_enc: 0.2509 (0.5093)  loss_giou_enc: 0.3070 (0.4485)  loss_ce_unscaled: 1.0949 (1.0995)  class_error_unscaled: 100.0000 (62.0256)  loss_bbox_unscaled: 0.0178 (0.0772)  loss_giou_unscaled: 0.0633 (0.1715)  cardinality_error_unscaled: 3899.0000 (3893.7000)  loss_ce_0_unscaled: 1.1171 (1.1193)  loss_bbox_0_unscaled: 0.0214 (0.0681)  loss_giou_0_unscaled: 0.0706 (0.1665)  cardinality_error_0_unscaled: 3898.0000 (3893.5667)  loss_ce_enc_unscaled: 1.0712 (1.0785)  loss_bbox_enc_unscaled: 0.0502 (0.1019)  loss_giou_enc_unscaled: 0.1535 (0.2243)  cardinality_error_enc_unscaled: 3899.0000 (3891.9333)
# Test:  [  0/121]  eta: 0:00:41  class_error: 50.00  loss: 4.1707 (4.1707)  loss_ce: 1.0859 (1.0859)  loss_bbox: 0.0404 (0.0404)  loss_giou: 0.0892 (0.0892)  loss_ce_0: 1.0938 (1.0938)  loss_bbox_0: 0.0556 (0.0556)  loss_giou_0: 0.1308 (0.1308)  loss_ce_enc: 1.0234 (1.0234)  loss_bbox_enc: 0.2344 (0.2344)  loss_giou_enc: 0.4173 (0.4173)  loss_ce_unscaled: 1.0859 (1.0859)  class_error_unscaled: 50.0000 (50.0000)  loss_bbox_unscaled: 0.0081 (0.0081)  loss_giou_unscaled: 0.0446 (0.0446)  cardinality_error_unscaled: 298.0000 (298.0000)  loss_ce_0_unscaled: 1.0938 (1.0938)  loss_bbox_0_unscaled: 0.0111 (0.0111)  loss_giou_0_unscaled: 0.0654 (0.0654)  cardinality_error_0_unscaled: 298.0000 (298.0000)  loss_ce_enc_unscaled: 1.0234 (1.0234)  loss_bbox_enc_unscaled: 0.0469 (0.0469)  loss_giou_enc_unscaled: 0.2086 (0.2086)  cardinality_error_enc_unscaled: 298.0000 (298.0000)  time: 0.3423  data: 0.2776  max mem: 1204
# Test:  [ 10/121]  eta: 0:00:16  class_error: 50.00  loss: 4.3076 (4.3075)  loss_ce: 1.0391 (1.0717)  loss_bbox: 0.0706 (0.0894)  loss_giou: 0.1302 (0.1813)  loss_ce_0: 1.0781 (1.0945)  loss_bbox_0: 0.0721 (0.0978)  loss_giou_0: 0.1799 (0.2069)  loss_ce_enc: 1.0234 (1.0408)  loss_bbox_enc: 0.1682 (0.1955)  loss_giou_enc: 0.3236 (0.3297)  loss_ce_unscaled: 1.0391 (1.0717)  class_error_unscaled: 50.0000 (53.0303)  loss_bbox_unscaled: 0.0141 (0.0179)  loss_giou_unscaled: 0.0651 (0.0907)  cardinality_error_unscaled: 298.0000 (297.9091)  loss_ce_0_unscaled: 1.0781 (1.0945)  loss_bbox_0_unscaled: 0.0144 (0.0196)  loss_giou_0_unscaled: 0.0900 (0.1034)  cardinality_error_0_unscaled: 298.0000 (297.9091)  loss_ce_enc_unscaled: 1.0234 (1.0408)  loss_bbox_enc_unscaled: 0.0336 (0.0391)  loss_giou_enc_unscaled: 0.1618 (0.1648)  cardinality_error_enc_unscaled: 298.0000 (297.9091)  time: 0.1531  data: 0.0717  max mem: 1204
# Test:  [ 20/121]  eta: 0:00:10  class_error: 100.00  loss: 4.3699 (4.4118)  loss_ce: 1.0391 (1.0582)  loss_bbox: 0.0887 (0.1254)  loss_giou: 0.2019 (0.2251)  loss_ce_0: 1.0781 (1.0938)  loss_bbox_0: 0.0861 (0.1259)  loss_giou_0: 0.1799 (0.2322)  loss_ce_enc: 1.0547 (1.0376)  loss_bbox_enc: 0.1682 (0.1965)  loss_giou_enc: 0.3071 (0.3170)  loss_ce_unscaled: 1.0391 (1.0582)  class_error_unscaled: 50.0000 (47.6190)  loss_bbox_unscaled: 0.0177 (0.0251)  loss_giou_unscaled: 0.1010 (0.1125)  cardinality_error_unscaled: 298.0000 (298.2381)  loss_ce_0_unscaled: 1.0781 (1.0938)  loss_bbox_0_unscaled: 0.0172 (0.0252)  loss_giou_0_unscaled: 0.0900 (0.1161)  cardinality_error_0_unscaled: 299.0000 (298.2857)  loss_ce_enc_unscaled: 1.0547 (1.0376)  loss_bbox_enc_unscaled: 0.0336 (0.0393)  loss_giou_enc_unscaled: 0.1535 (0.1585)  cardinality_error_enc_unscaled: 298.0000 (298.2381)  time: 0.0966  data: 0.0315  max mem: 1204
# Test:  [ 30/121]  eta: 0:00:11  class_error: 100.00  loss: 4.3568 (4.2772)  loss_ce: 1.0938 (1.0353)  loss_bbox: 0.0750 (0.1085)  loss_giou: 0.1646 (0.2144)  loss_ce_0: 1.1172 (1.0817)  loss_bbox_0: 0.0735 (0.1094)  loss_giou_0: 0.1481 (0.2216)  loss_ce_enc: 1.0547 (1.0249)  loss_bbox_enc: 0.1269 (0.1730)  loss_giou_enc: 0.2670 (0.3084)  loss_ce_unscaled: 1.0938 (1.0353)  class_error_unscaled: 50.0000 (46.7742)  loss_bbox_unscaled: 0.0150 (0.0217)  loss_giou_unscaled: 0.0823 (0.1072)  cardinality_error_unscaled: 298.0000 (298.2258)  loss_ce_0_unscaled: 1.1172 (1.0817)  loss_bbox_0_unscaled: 0.0147 (0.0219)  loss_giou_0_unscaled: 0.0740 (0.1108)  cardinality_error_0_unscaled: 299.0000 (298.2581)  loss_ce_enc_unscaled: 1.0547 (1.0249)  loss_bbox_enc_unscaled: 0.0254 (0.0346)  loss_giou_enc_unscaled: 0.1335 (0.1542)  cardinality_error_enc_unscaled: 298.0000 (298.2258)  time: 0.1170  data: 0.0688  max mem: 1204
# ...
# Test:  [ 30/121]  eta: 0:00:13  class_error: 100.00  loss: 2.2352 (3.1704)  loss_ce: 0.3848 (0.7424)  loss_bbox: 0.0813 (0.0959)  loss_giou: 0.1481 (0.2063)  loss_ce_0: 0.5625 (0.7526)  loss_bbox_0: 0.0849 (0.0987)  loss_giou_0: 0.1447 (0.2067)  loss_ce_enc: 0.5195 (0.7409)  loss_bbox_enc: 0.0905 (0.1070)  loss_giou_enc: 0.1485 (0.2199)  loss_ce_unscaled: 0.3848 (0.7424)  class_error_unscaled: 0.0000 (29.0323)  loss_bbox_unscaled: 0.0163 (0.0192)  loss_giou_unscaled: 0.0741 (0.1032)  cardinality_error_unscaled: 299.0000 (298.2581)  loss_ce_0_unscaled: 0.5625 (0.7526)  loss_bbox_0_unscaled: 0.0170 (0.0197)  loss_giou_0_unscaled: 0.0724 (0.1033)  cardinality_error_0_unscaled: 299.0000 (298.2581)  loss_ce_enc_unscaled: 0.5195 (0.7409)  loss_bbox_enc_unscaled: 0.0181 (0.0214)  loss_giou_enc_unscaled: 0.0743 (0.1100)  cardinality_error_enc_unscaled: 299.0000 (298.2581)  time: 0.1553  data: 0.0868  max mem: 1204
# Test:  [ 40/121]  eta: 0:00:11  class_error: 0.00  loss: 2.3136 (3.3226)  loss_ce: 0.3848 (0.7219)  loss_bbox: 0.0794 (0.1311)  loss_giou: 0.1138 (0.2160)  loss_ce_0: 0.7148 (0.7354)  loss_bbox_0: 0.0865 (0.1392)  loss_giou_0: 0.1191 (0.2143)  loss_ce_enc: 0.7266 (0.7442)  loss_bbox_enc: 0.1590 (0.1791)  loss_giou_enc: 0.1721 (0.2414)  loss_ce_unscaled: 0.3848 (0.7219)  class_error_unscaled: 0.0000 (29.2683)  loss_bbox_unscaled: 0.0159 (0.0262)  loss_giou_unscaled: 0.0569 (0.1080)  cardinality_error_unscaled: 299.0000 (298.4146)  loss_ce_0_unscaled: 0.7148 (0.7354)  loss_bbox_0_unscaled: 0.0173 (0.0278)  loss_giou_0_unscaled: 0.0595 (0.1072)  cardinality_error_0_unscaled: 299.0000 (298.4146)  loss_ce_enc_unscaled: 0.7266 (0.7442)  loss_bbox_enc_unscaled: 0.0318 (0.0358)  loss_giou_enc_unscaled: 0.0860 (0.1207)  cardinality_error_enc_unscaled: 299.0000 (298.4146)  time: 0.1479  data: 0.0830  max mem: 1204
# Test:  [ 50/121]  eta: 0:00:08  class_error: 0.00  loss: 3.2044 (3.5915)  loss_ce: 0.6562 (0.7139)  loss_bbox: 0.1418 (0.1801)  loss_giou: 0.1215 (0.2727)  loss_ce_0: 0.5664 (0.7176)  loss_bbox_0: 0.1428 (0.1858)  loss_giou_0: 0.1298 (0.2751)  loss_ce_enc: 0.8242 (0.7408)  loss_bbox_enc: 0.2453 (0.2194)  loss_giou_enc: 0.2076 (0.2862)  loss_ce_unscaled: 0.6562 (0.7139)  class_error_unscaled: 0.0000 (28.4314)  loss_bbox_unscaled: 0.0284 (0.0360)  loss_giou_unscaled: 0.0607 (0.1364)  cardinality_error_unscaled: 299.0000 (298.4706)  loss_ce_0_unscaled: 0.5664 (0.7176)  loss_bbox_0_unscaled: 0.0286 (0.0372)  loss_giou_0_unscaled: 0.0649 (0.1375)  cardinality_error_0_unscaled: 299.0000 (298.4706)  loss_ce_enc_unscaled: 0.8242 (0.7408)  loss_bbox_enc_unscaled: 0.0491 (0.0439)  loss_giou_enc_unscaled: 0.1038 (0.1431)  cardinality_error_enc_unscaled: 299.0000 (298.4706)  time: 0.0811  data: 0.0156  max mem: 1204
# Test:  [ 60/121]  eta: 0:00:07  class_error: 0.00  loss: 1.8720 (3.3764)  loss_ce: 0.2832 (0.6509)  loss_bbox: 0.0747 (0.1714)  loss_giou: 0.1078 (0.2623)  loss_ce_0: 0.4551 (0.6705)  loss_bbox_0: 0.0807 (0.1756)  loss_giou_0: 0.1146 (0.2599)  loss_ce_enc: 0.4746 (0.6991)  loss_bbox_enc: 0.1430 (0.2124)  loss_giou_enc: 0.1594 (0.2743)  loss_ce_unscaled: 0.2832 (0.6509)  class_error_unscaled: 0.0000 (24.5902)  loss_bbox_unscaled: 0.0149 (0.0343)  loss_giou_unscaled: 0.0539 (0.1312)  cardinality_error_unscaled: 299.0000 (298.4426)  loss_ce_0_unscaled: 0.4551 (0.6705)  loss_bbox_0_unscaled: 0.0161 (0.0351)  loss_giou_0_unscaled: 0.0573 (0.1299)  cardinality_error_0_unscaled: 299.0000 (298.4426)  loss_ce_enc_unscaled: 0.4746 (0.6991)  loss_bbox_enc_unscaled: 0.0286 (0.0425)  loss_giou_enc_unscaled: 0.0797 (0.1372)  cardinality_error_enc_unscaled: 299.0000 (298.4426)  time: 0.0807  data: 0.0131  max mem: 1204
# Test:  [ 70/121]  eta: 0:00:05  class_error: 0.00  loss: 1.6613 (3.6332)  loss_ce: 0.2695 (0.7404)  loss_bbox: 0.0649 (0.1775)  loss_giou: 0.1078 (0.2624)  loss_ce_0: 0.4551 (0.7537)  loss_bbox_0: 0.0693 (0.1828)  loss_giou_0: 0.0999 (0.2623)  loss_ce_enc: 0.4355 (0.7553)  loss_bbox_enc: 0.1292 (0.2200)  loss_giou_enc: 0.1427 (0.2788)  loss_ce_unscaled: 0.2695 (0.7404)  class_error_unscaled: 0.0000 (27.4648)  loss_bbox_unscaled: 0.0130 (0.0355)  loss_giou_unscaled: 0.0539 (0.1312)  cardinality_error_unscaled: 299.0000 (298.4789)  loss_ce_0_unscaled: 0.4551 (0.7537)  loss_bbox_0_unscaled: 0.0139 (0.0366)  loss_giou_0_unscaled: 0.0500 (0.1311)  cardinality_error_0_unscaled: 299.0000 (298.4789)  loss_ce_enc_unscaled: 0.4355 (0.7553)  loss_bbox_enc_unscaled: 0.0258 (0.0440)  loss_giou_enc_unscaled: 0.0713 (0.1394)  cardinality_error_enc_unscaled: 299.0000 (298.4789)  time: 0.0833  data: 0.0158  max mem: 1204
# Test:  [ 80/121]  eta: 0:00:04  class_error: 0.00  loss: 2.3700 (3.6296)  loss_ce: 0.4277 (0.7529)  loss_bbox: 0.0723 (0.1734)  loss_giou: 0.1198 (0.2509)  loss_ce_0: 0.4785 (0.7716)  loss_bbox_0: 0.0730 (0.1782)  loss_giou_0: 0.1285 (0.2510)  loss_ce_enc: 0.5195 (0.7700)  loss_bbox_enc: 0.1415 (0.2139)  loss_giou_enc: 0.1434 (0.2678)  loss_ce_unscaled: 0.4277 (0.7529)  class_error_unscaled: 0.0000 (26.9547)  loss_bbox_unscaled: 0.0145 (0.0347)  loss_giou_unscaled: 0.0599 (0.1254)  cardinality_error_unscaled: 299.0000 (298.5062)  loss_ce_0_unscaled: 0.4785 (0.7716)  loss_bbox_0_unscaled: 0.0146 (0.0356)  loss_giou_0_unscaled: 0.0643 (0.1255)  cardinality_error_0_unscaled: 299.0000 (298.5062)  loss_ce_enc_unscaled: 0.5195 (0.7700)  loss_bbox_enc_unscaled: 0.0283 (0.0428)  loss_giou_enc_unscaled: 0.0717 (0.1339)  cardinality_error_enc_unscaled: 299.0000 (298.5062)  time: 0.0795  data: 0.0153  max mem: 1204
# Test:  [ 90/121]  eta: 0:00:03  class_error: 0.00  loss: 2.5713 (3.5012)  loss_ce: 0.4277 (0.7121)  loss_bbox: 0.1008 (0.1725)  loss_giou: 0.1198 (0.2415)  loss_ce_0: 0.4355 (0.7336)  loss_bbox_0: 0.0979 (0.1733)  loss_giou_0: 0.1285 (0.2394)  loss_ce_enc: 0.5586 (0.7475)  loss_bbox_enc: 0.1591 (0.2170)  loss_giou_enc: 0.1464 (0.2643)  loss_ce_unscaled: 0.4277 (0.7121)  class_error_unscaled: 0.0000 (25.4579)  loss_bbox_unscaled: 0.0202 (0.0345)  loss_giou_unscaled: 0.0599 (0.1208)  cardinality_error_unscaled: 299.0000 (298.4835)  loss_ce_0_unscaled: 0.4355 (0.7336)  loss_bbox_0_unscaled: 0.0196 (0.0347)  loss_giou_0_unscaled: 0.0643 (0.1197)  cardinality_error_0_unscaled: 299.0000 (298.4835)  loss_ce_enc_unscaled: 0.5586 (0.7475)  loss_bbox_enc_unscaled: 0.0318 (0.0434)  loss_giou_enc_unscaled: 0.0732 (0.1321)  cardinality_error_enc_unscaled: 299.0000 (298.4835)  time: 0.0795  data: 0.0168  max mem: 1204
# Test:  [100/121]  eta: 0:00:02  class_error: 0.00  loss: 2.4555 (3.5810)  loss_ce: 0.3262 (0.6881)  loss_bbox: 0.1008 (0.2157)  loss_giou: 0.1019 (0.2529)  loss_ce_0: 0.3125 (0.7142)  loss_bbox_0: 0.0979 (0.2005)  loss_giou_0: 0.1099 (0.2439)  loss_ce_enc: 0.4102 (0.7234)  loss_bbox_enc: 0.1856 (0.2636)  loss_giou_enc: 0.1647 (0.2785)  loss_ce_unscaled: 0.3262 (0.6881)  class_error_unscaled: 0.0000 (22.9373)  loss_bbox_unscaled: 0.0202 (0.0431)  loss_giou_unscaled: 0.0510 (0.1265)  cardinality_error_unscaled: 299.0000 (298.5347)  loss_ce_0_unscaled: 0.3125 (0.7142)  loss_bbox_0_unscaled: 0.0196 (0.0401)  loss_giou_0_unscaled: 0.0550 (0.1220)  cardinality_error_0_unscaled: 299.0000 (298.5347)  loss_ce_enc_unscaled: 0.4102 (0.7234)  loss_bbox_enc_unscaled: 0.0371 (0.0527)  loss_giou_enc_unscaled: 0.0823 (0.1393)  cardinality_error_enc_unscaled: 299.0000 (298.5347)  time: 0.0800  data: 0.0164  max mem: 1204
# Test:  [110/121]  eta: 0:00:01  class_error: 100.00  loss: 3.1056 (3.7774)  loss_ce: 0.6094 (0.6979)  loss_bbox: 0.1318 (0.2432)  loss_giou: 0.1041 (0.2801)  loss_ce_0: 0.5820 (0.7155)  loss_bbox_0: 0.1145 (0.2343)  loss_giou_0: 0.1102 (0.2765)  loss_ce_enc: 0.7422 (0.7307)  loss_bbox_enc: 0.2340 (0.2915)  loss_giou_enc: 0.2256 (0.3076)  loss_ce_unscaled: 0.6094 (0.6979)  class_error_unscaled: 0.0000 (24.0240)  loss_bbox_unscaled: 0.0264 (0.0486)  loss_giou_unscaled: 0.0520 (0.1401)  cardinality_error_unscaled: 299.0000 (298.5676)  loss_ce_0_unscaled: 0.5820 (0.7155)  loss_bbox_0_unscaled: 0.0229 (0.0469)  loss_giou_0_unscaled: 0.0551 (0.1383)  cardinality_error_0_unscaled: 299.0000 (298.5676)  loss_ce_enc_unscaled: 0.7422 (0.7307)  loss_bbox_enc_unscaled: 0.0468 (0.0583)  loss_giou_enc_unscaled: 0.1128 (0.1538)  cardinality_error_enc_unscaled: 299.0000 (298.5676)  time: 0.1063  data: 0.0426  max mem: 1204
# Test:  [120/121]  eta: 0:00:00  class_error: 100.00  loss: 8.1483 (4.1944)  loss_ce: 0.9180 (0.7325)  loss_bbox: 0.7680 (0.3036)  loss_giou: 0.8118 (0.3332)  loss_ce_0: 0.9258 (0.7492)  loss_bbox_0: 0.8165 (0.2924)  loss_giou_0: 0.8203 (0.3271)  loss_ce_enc: 0.8750 (0.7558)  loss_bbox_enc: 0.7054 (0.3449)  loss_giou_enc: 0.8589 (0.3558)  loss_ce_unscaled: 0.9180 (0.7325)  class_error_unscaled: 100.0000 (28.6501)  loss_bbox_unscaled: 0.1536 (0.0607)  loss_giou_unscaled: 0.4059 (0.1666)  cardinality_error_unscaled: 299.0000 (298.5702)  loss_ce_0_unscaled: 0.9258 (0.7492)  loss_bbox_0_unscaled: 0.1633 (0.0585)  loss_giou_0_unscaled: 0.4101 (0.1636)  cardinality_error_0_unscaled: 299.0000 (298.5702)  loss_ce_enc_unscaled: 0.8750 (0.7558)  loss_bbox_enc_unscaled: 0.1411 (0.0690)  loss_giou_enc_unscaled: 0.4294 (0.1779)  cardinality_error_enc_unscaled: 299.0000 (298.5702)  time: 0.1331  data: 0.0685  max mem: 1204
# Test: Total time: 0:00:13 (0.1091 s / it)
# Averaged stats: class_error: 100.00  loss: 8.1483 (4.1944)  loss_ce: 0.9180 (0.7325)  loss_bbox: 0.7680 (0.3036)  loss_giou: 0.8118 (0.3332)  loss_ce_0: 0.9258 (0.7492)  loss_bbox_0: 0.8165 (0.2924)  loss_giou_0: 0.8203 (0.3271)  loss_ce_enc: 0.8750 (0.7558)  loss_bbox_enc: 0.7054 (0.3449)  loss_giou_enc: 0.8589 (0.3558)  loss_ce_unscaled: 0.9180 (0.7325)  class_error_unscaled: 100.0000 (28.6501)  loss_bbox_unscaled: 0.1536 (0.0607)  loss_giou_unscaled: 0.4059 (0.1666)  cardinality_error_unscaled: 299.0000 (298.5702)  loss_ce_0_unscaled: 0.9258 (0.7492)  loss_bbox_0_unscaled: 0.1633 (0.0585)  loss_giou_0_unscaled: 0.4101 (0.1636)  cardinality_error_0_unscaled: 299.0000 (298.5702)  loss_ce_enc_unscaled: 0.8750 (0.7558)  loss_bbox_enc_unscaled: 0.1411 (0.0690)  loss_giou_enc_unscaled: 0.4294 (0.1779)  cardinality_error_enc_unscaled: 299.0000 (298.5702)
# Accumulating evaluation results...
# DONE (t=0.26s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.564
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.694
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.710
# Test results: {'class_error': 28.65013784613491, 'loss': 4.19436812597858, 'loss_ce': 0.7325106534090909, 'loss_bbox': 0.3035865934981295, 'loss_giou': 0.33321708373048087, 'loss_ce_0': 0.7491566051136364, 'loss_bbox_0': 0.29236932209700595, 'loss_giou_0': 0.32710274869252826, 'loss_ce_enc': 0.7557625258264463, 'loss_bbox_enc': 0.34485428986593714, 'loss_giou_enc': 0.3558083101491298, 'loss_ce_unscaled': 0.7325106534090909, 'class_error_unscaled': 28.65013784613491, 'loss_bbox_unscaled': 0.06071731865344461, 'loss_giou_unscaled': 0.16660854186524043, 'cardinality_error_unscaled': 298.5702479338843, 'loss_ce_0_unscaled': 0.7491566051136364, 'loss_bbox_0_unscaled': 0.05847386497049785, 'loss_giou_0_unscaled': 0.16355137434626413, 'cardinality_error_0_unscaled': 298.5702479338843, 'loss_ce_enc_unscaled': 0.7557625258264463, 'loss_bbox_enc_unscaled': 0.06897085860433165, 'loss_giou_enc_unscaled': 0.1779041550745649, 'cardinality_error_enc_unscaled': 298.5702479338843, 'results_json': {'class_map': [{'class': 'Animal', 'map@50:95': 0.05097512934317304, 'map@50': 0.059649307105776886, 'precision': np.float64(0.0), 'recall': np.float64(0.0)}, {'class': 'Blind-Spot Mirror (Convex)', 'map@50:95': 0.6760478220229946, 'map@50': 0.7313514076565139, 'precision': np.float64(0.6923076923076923), 'recall': np.float64(0.75)}, {'class': 'Bump', 'map@50:95': 0.0066079729749354, 'map@50': 0.01851851851851852, 'precision': np.float64(0.0), 'recall': np.float64(0.0)}, {'class': 'Give way', 'map@50:95': 0.737527772172964, 'map@50': 0.8379269587858438, 'precision': np.float64(1.0), 'recall': np.float64(0.8181818181818182)}, {'class': 'No Entry (One Way)', 'map@50:95': 0.6039074446165311, 'map@50': 0.6820322059450109, 'precision': np.float64(0.8275862068965517), 'recall': np.float64(0.6666666666666666)}, {'class': 'No Stopping', 'map@50:95': 0.6551249799703979, 'map@50': 0.806650476368391, 'precision': np.float64(1.0), 'recall': np.float64(0.8)}, {'class': 'No Through Road (T-sign)', 'map@50:95': 0.5379550034111296, 'map@50': 0.5988857869174616, 'precision': np.float64(1.0), 'recall': np.float64(0.375)}, {'class': 'No Turn (left/right)', 'map@50:95': 0.5555316925871794, 'map@50': 0.6036147476640248, 'precision': np.float64(0.8), 'recall': np.float64(0.47058823529411764)}, {'class': 'No U-turn', 'map@50:95': 0.8999999999999998, 'map@50': 0.9999999999999999, 'precision': np.float64(1.0), 'recall': np.float64(1.0)}, {'class': 'No Waiting', 'map@50:95': 0.0, 'map@50': 0.0, 'precision': np.float64(0.0), 'recall': np.float64(0.0)}, {'class': 'Parking', 'map@50:95': 0.0, 'map@50': 0.0, 'precision': np.float64(0.0), 'recall': np.float64(0.0)}, {'class': 'Pedestrian Crossing', 'map@50:95': 0.6441253293835487, 'map@50': 0.7762141715456284, 'precision': np.float64(0.8181818181818182), 'recall': np.float64(0.6428571428571429)}, {'class': 'Roundabout Ahead', 'map@50:95': 0.5753889674681754, 'map@50': 0.7043847241867045, 'precision': np.float64(1.0), 'recall': np.float64(0.6)}, {'class': 'Speed Limit', 'map@50:95': 0.6961152365236523, 'map@50': 0.9130913091309129, 'precision': np.float64(0.7142857142857143), 'recall': np.float64(0.7142857142857143)}, {'class': 'Stop', 'map@50:95': 0.5648112954394149, 'map@50': 0.6236285790741235, 'precision': np.float64(0.8333333333333334), 'recall': np.float64(0.5882352941176471)}, {'class': 'Traffic Light', 'map@50:95': 0.5, 'map@50': 0.5, 'precision': np.float64(0.0), 'recall': np.float64(0.0)}, {'class': 'Turn (left/right)', 'map@50:95': 0.6777300042660787, 'map@50': 0.8085808580858086, 'precision': np.float64(1.0), 'recall': np.float64(0.7777777777777778)}, {'class': 'Two-way traffic', 'map@50:95': 0.8999999999999998, 'map@50': 0.9999999999999999, 'precision': np.float64(0.5), 'recall': np.float64(1.0)}, {'class': 'Uneven Road', 'map@50:95': 0.7524752475247525, 'map@50': 0.7524752475247525, 'precision': np.float64(0.5), 'recall': np.float64(0.5)}, {'class': 'all', 'map@50:95': 0.5281223104055225, 'map@50': 0.600894963079446, ' ...
# Results saved to /home/yukkami/cv/runs/2a_rfdetr/rfdetr_outputs/metrics_plot.png
#
# RF-DETR training finished.
# Artifacts saved to: /home/yukkami/cv/runs/2a_rfdetr/rfdetr_outputs

# %%
from pathlib import Path
import json
import torch
from torchmetrics.detection.mean_ap import MeanAveragePrecision

VAL_SPLIT = "valid"
PRED_THRESHOLD = 0.001

val_dir = Path(rfdetr_root) / VAL_SPLIT
ann_path = val_dir / "_annotations.coco.json"
assert ann_path.exists(), f"Missing validation annotations: {ann_path}"

with open(ann_path, "r", encoding="utf-8") as f:
    coco = json.load(f)

img_id_to_name = {im["id"]: im["file_name"] for im in coco.get("images", [])}

cat_ids = sorted([c["id"] for c in coco.get("categories", [])])
catid_to_label = {cid: i for i, cid in enumerate(cat_ids)}
label_to_catid = {i: cid for cid, i in catid_to_label.items()}

gt_by_img = {}
for a in coco.get("annotations", []):
    img_id = a["image_id"]
    gt_by_img.setdefault(img_id, []).append(a)

metric = MeanAveragePrecision(iou_type="bbox")

def coco_xywh_to_xyxy(xywh):
    x, y, w, h = xywh
    return [x, y, x + w, y + h]

def map_pred_cat_id(raw_class_id: int) -> int:
    cid = int(raw_class_id)
    if cid in catid_to_label:
        return cid
    if (cid + 1) in catid_to_label:
        return cid + 1
    if len(cat_ids) == 1:
        return cat_ids[0]
    return cat_ids[max(0, min(len(cat_ids) - 1, cid))]

def to_jsonable(v):
    if isinstance(v, torch.Tensor):
        if v.numel() == 1:
            return float(v.item())
        return v.detach().cpu().tolist()
    if hasattr(v, "item") and callable(v.item):
        try:
            return float(v.item())
        except Exception:
            pass
    return v

torch.set_grad_enabled(False)

num_images = len(img_id_to_name)
print(f"Running validation on {num_images} images from: {val_dir}")

for idx, (img_id, fname) in enumerate(img_id_to_name.items(), start=1):
    img_path = val_dir / fname
    if not img_path.exists():
        img_path = val_dir / Path(fname).name
    if not img_path.exists():
        raise FileNotFoundError(f"Missing image referenced in COCO JSON: {fname}")

    anns = gt_by_img.get(img_id, [])
    gt_boxes = []
    gt_labels = []
    for a in anns:
        gt_boxes.append(coco_xywh_to_xyxy(a["bbox"]))
        gt_labels.append(catid_to_label[a["category_id"]])

    target = {
        "boxes": torch.tensor(gt_boxes, dtype=torch.float32),
        "labels": torch.tensor(gt_labels, dtype=torch.int64),
    }

    det = rfdetr_model.predict(str(img_path), threshold=PRED_THRESHOLD)

    if getattr(det, "xyxy", None) is None or len(det) == 0:
        pred = {
            "boxes": torch.zeros((0, 4), dtype=torch.float32),
            "scores": torch.zeros((0,), dtype=torch.float32),
            "labels": torch.zeros((0,), dtype=torch.int64),
        }
    else:
        pred_boxes = torch.tensor(det.xyxy, dtype=torch.float32)
        pred_scores = torch.tensor(det.confidence, dtype=torch.float32)

        raw_cls = det.class_id
        if raw_cls is None:
            raw_cls = [cat_ids[0]] * len(det)

        pred_cat_ids = [map_pred_cat_id(c) for c in raw_cls]
        pred_labels = torch.tensor([catid_to_label[cid] for cid in pred_cat_ids], dtype=torch.int64)

        pred = {
            "boxes": pred_boxes,
            "scores": pred_scores,
            "labels": pred_labels,
        }

    metric.update([pred], [target])

    if device.type == "cuda":
        torch.cuda.empty_cache()

    if idx % max(1, num_images // 10) == 0 or idx == num_images:
        print(f"  progress: {idx}/{num_images}")

results = metric.compute()

print("\nRF-DETR validation results (TorchMetrics):")
for k in ["map", "map_50", "map_75", "mar_1", "mar_10", "mar_100"]:
    if k in results:
        print(f"  {k}: {to_jsonable(results[k]):.4f}")

save_keys = [
    "map", "map_50", "map_75",
    "map_small", "map_medium", "map_large",
    "mar_1", "mar_10", "mar_100",
    "mar_small", "mar_medium", "mar_large",
    "map_per_class", "mar_100_per_class", "classes",
]

results_compact = {k: to_jsonable(results[k]) for k in save_keys if k in results}

metrics_path = Path(rfdetr_out) / "val_metrics_torchmetrics.json"
with open(metrics_path, "w", encoding="utf-8") as f:
    json.dump(results_compact, f, indent=2)

print("\nSaved metrics to:", metrics_path)

torch.set_grad_enabled(True)
# Out:
# Model is not optimized for inference. Latency may be higher than expected. You can optimize the model for inference by calling model.optimize_for_inference().
# Running validation on 121 images from: /home/yukkami/cv/runs/2a_rfdetr/rfdetr_data/valid
# UserWarning: Encountered more than 100 detections in a single image. This means that certain detections with the lowest scores will be ignored, that may have an undesirable impact on performance. Please consider adjusting the `max_detection_threshold` to suit your use case. To disable this warning, set attribute class `warn_on_many_detections=False`, after initializing the metric.
#   progress: 12/121
#   progress: 24/121
#   progress: 36/121
#   progress: 48/121
#   progress: 60/121
#   progress: 72/121
#   progress: 84/121
#   progress: 96/121
#   progress: 108/121
#   progress: 120/121
#   progress: 121/121
#
# RF-DETR validation results (TorchMetrics):
#   map: 0.5436
#   map_50: 0.6160
#   map_75: 0.5911
#   mar_1: 0.6196
#   mar_10: 0.6857
#   mar_100: 0.7091
#
# Saved metrics to: /home/yukkami/cv/runs/2a_rfdetr/rfdetr_outputs/val_metrics_torchmetrics.json
# torch.autograd.grad_mode.set_grad_enabled(mode=True)

# %%
from pathlib import Path
import json
from IPython.display import display

val_dir = Path(rfdetr_root) / "valid"
ann_path = val_dir / "_annotations.coco.json"

with open(ann_path, "r", encoding="utf-8") as f:
    coco = json.load(f)

imgs = coco.get("images", [])
sel = imgs[:3] if len(imgs) >= 3 else imgs

out_imgs = []
for i, info in enumerate(sel, start=1):
    img_path = val_dir / info["file_name"]
    if not img_path.exists():
        img_path = val_dir / Path(info["file_name"]).name

    preds = rfdetr_model.predict(str(img_path), threshold=0.001)

    out_img = draw_predictions(
        img_path,
        preds,
        score_thr=0.3,
        save_path=str(Path(rfdetr_out) / f"debug_pred_vis_320_{i}.jpg"),
        rfdetr_model_for_names=rfdetr_model,
        coco_json_for_names=ann_path,
        resize_to=(320, 600),
        font_scale=0.06,
    )
    display(out_img)
    out_imgs.append(out_img)

out_imgs
# Out:
# <PIL.Image.Image image mode=RGB size=320x600>
# <PIL.Image.Image image mode=RGB size=320x600>
# <PIL.Image.Image image mode=RGB size=320x600>
# [<PIL.Image.Image image mode=RGB size=320x600>,
#  <PIL.Image.Image image mode=RGB size=320x600>,
#  <PIL.Image.Image image mode=RGB size=320x600>]
